# %%
import os
import tqdm
import wandb
import warnings
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import concurrent.futures

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TensorFlow logging
warnings.filterwarnings('ignore', category=UserWarning, module='google.protobuf')

from matplotlib.axes import Axes
from wandb.apis.public import Run

from typing import Union, List, Dict
from src.visualization import set_themes

set_themes() # Set custom themes for plots
pl.Config.set_tbl_rows(20) # Set Polars table display rows limit

pd.set_option('future.no_silent_downcasting', True)
# Out:
#             <style>
#                 .jupyter-widgets.widget-inline-hbox,
#                 .jupyter-widgets.widget-box,
#                 .jupyter-matplotlib-canvas,
#                 .jupyter-matplotlib,
#                 .widget-output,
#                 .jp-OutputArea-output,
#                 .jp-OutputArea-child,
#                 .jp-OutputArea,
#                 .jp-Cell-outputWrapper,
#                 div.output_subarea,
#                 div.output_area,
#                 .cell-output-ipywidget-background {
#                     background-color: grey !important;
#                     padding: 0 !important;
#                 }
#
#                 /* Target the canvas container specifically */
#                 canvas.jupyter-matplotlib-canvas {
#                     background-color: grey !important;
#                 }
#             </style>

# %%
cache_file = "wandb/summary.parquet"
config = {
    "model": "matrix_factorization",
    "ensure_available_locally": False
}
sorting_criterion = {
    "epoch/test_hitrate@50": 0.5,
    "epoch/test_ndcg@50": 0.25,
}

if cache_file is not None and os.path.exists(cache_file):
    print(f"Loading cached experiment runs from {cache_file}...")
    experiment_runs = pl.read_parquet(cache_file)
    print(f"Loaded {len(experiment_runs)} runs from cache.")
else:
    print("No cache file found. Fetching experiment runs from Weights & Biases...")
    api = wandb.Api() # Initialize Weights & Biases API, used for fetching run data

    def fetch_run_metadata(run: Run, considered_metrics: Union[str, Dict[str, float]] = "epoch/epoch") -> Dict:
        run_config = {}
        for key, value in run.config.items():
            # Convert lists and dicts to strings
            if isinstance(value, (list, dict)):
                run_config[key] = str(value)
            else:
                run_config[key] = value

        run_history = run.history()
        run_history = run_history.replace({"Infinity": np.inf, "NaN": np.nan})

        if isinstance(considered_metrics, str):
            run_history["score"] = run_history[considered_metrics]
        elif isinstance(considered_metrics, dict):
            run_history["score"] = sum(
                run_history[metric] * weight for metric, weight in considered_metrics.items()
            )
        else:
            raise ValueError("considered_metrics must be either a string or a dictionary")
        
        best_summary = run_history.iloc[run_history["score"].argmax()]
        best_summary = {f"best:{key}": val for key, val in best_summary.items()}
        
        return {
            "run_id": run.id,
            "run_name": run.name,
            "sweep_id": run.sweep.id if run.sweep else None,
            "model": run.config.get("model"),
            **run_config,
            **{metric: run_history[metric].to_list() for metric in run_history},
            **best_summary,
            "gpu_type": run.metadata.get("gpu"),
            "cpu_count": run.metadata.get("cpu_count"),
        }

    batch_size = 16
    records = []
    futures = {}
    executor = concurrent.futures.ThreadPoolExecutor(max_workers=batch_size)
    runs:List[Run] = api.runs("feedr/peppermint-matrix", per_page=2*batch_size-1, filters={"config.model": config["model"]})
    run_iterator = iter(runs)
    with tqdm.tqdm(total=len(runs), ncols=128) as pbar:
        while len(records) < len(runs):
            # submit new tasks if we empty slots in the batch
            while len(futures) < batch_size and len(records) + len(futures) < len(runs):
                current_runs = next(run_iterator)
                current_future = executor.submit(fetch_run_metadata, current_runs, sorting_criterion)
                futures[current_future] = current_runs

            # check for completed tasks
            finished_futures, _ = concurrent.futures.wait(futures.keys(), return_when=concurrent.futures.FIRST_COMPLETED, timeout=0.1)
            for finished_future in finished_futures:
                finished_run = futures.pop(finished_future)
                records.append(finished_future.result())
                pbar.update(1)

    # Create a Polars DataFrame from the records
    experiment_runs = pl.DataFrame(records, infer_schema_length=None)
    
# Tag run as available locally if the model files exist
local_run_ids = []
local_sweep_ids = os.listdir(f"./models/{config['model']}/")
for sweep_id in local_sweep_ids:
    local_run_ids.extend([run_id for run_id in os.listdir(f"./models/{config['model']}/{sweep_id}/")])
    
experiment_runs = experiment_runs.with_columns(
    available_locally=pl.col("run_id").is_in(local_run_ids)
)

if config["ensure_available_locally"]:
    experiment_runs = experiment_runs.filter(pl.col("available_locally") == True)

experiment_runs = experiment_runs.sort("_timestamp", descending=False)
experiment_runs = experiment_runs.with_columns(
    run_duration_second=pl.col("_runtime").list.max(),
    run_duration_minute=(pl.col("_runtime").list.max() / 60)
)
experiment_runs.select(
    pl.col("run_id"),
    pl.col("run_name"),
    pl.col("sweep_id"),
    pl.col("model"),
    pl.col("embedding_dimension"),
    pl.col("shuffle"),
    pl.col("best:epoch/epoch"),
    pl.col("best:epoch/train_loss"),
    pl.col("best:epoch/test_loss"),
    pl.col("best:epoch/test_recall@10"),
    pl.col("best:epoch/test_ndcg@10"),
)
# Out:
# Loading cached experiment runs from wandb/summary.parquet...
# Loaded 2343 runs from cache.
# shape: (2_343, 11)
# ┌──────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ run_id   ┆ run_name   ┆ sweep_id ┆ model     ┆ … ┆ best:epoc ┆ best:epoc ┆ best:epoc ┆ best:epoc │
# │ ---      ┆ ---        ┆ ---      ┆ ---       ┆   ┆ h/train_l ┆ h/test_lo ┆ h/test_re ┆ h/test_nd │
# │ str      ┆ str        ┆ str      ┆ str       ┆   ┆ oss       ┆ ss        ┆ call@10   ┆ cg@10     │
# │          ┆            ┆          ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆            ┆          ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞══════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ o94q0juk ┆ logical-sw ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.330564  ┆ 0.372714  ┆ 0.026077  ┆ 0.100539  │
# │          ┆ eep-1      ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ 4ftaae0p ┆ stilted-sw ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.693148  ┆ 0.693148  ┆ 0.006594  ┆ 0.02556   │
# │          ┆ eep-3      ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ fway5u2z ┆ breezy-swe ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.693147  ┆ 0.693147  ┆ 0.0026    ┆ 0.012059  │
# │          ┆ ep-4       ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ bphcl2xf ┆ clean-swee ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.237272  ┆ 0.239171  ┆ 0.024744  ┆ 0.095121  │
# │          ┆ p-2        ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ fftz1dek ┆ trim-sweep ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.319744  ┆ 0.366027  ┆ 0.025562  ┆ 0.099834  │
# │          ┆ -5         ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ otb8suw9 ┆ scarlet-sw ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.133806  ┆ 0.217083  ┆ 0.021467  ┆ 0.082659  │
# │          ┆ eep-6      ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ lvre7srl ┆ solar-swee ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.036125  ┆ 0.194509  ┆ 0.021456  ┆ 0.084617  │
# │          ┆ p-7        ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ dcbj92eg ┆ ruby-sweep ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.078173  ┆ 0.179263  ┆ 0.024295  ┆ 0.094158  │
# │          ┆ -8         ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ x17mnyw8 ┆ breezy-swe ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.111218  ┆ 0.207902  ┆ 0.023699  ┆ 0.089898  │
# │          ┆ ep-9       ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ 7jrm756b ┆ super-swee ┆ nbysw136 ┆ matrix_fa ┆ … ┆ 0.693147  ┆ 0.693147  ┆ 0.002425  ┆ 0.010531  │
# │          ┆ p-10       ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …          ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ fk6lh9vy ┆ splendid-s ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.699456  ┆ 0.701026  ┆ 0.013931  ┆ 0.057219  │
# │          ┆ weep-183   ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ y5d8amfz ┆ volcanic-s ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 1.239571  ┆ 0.936066  ┆ 0.00028   ┆ 0.001019  │
# │          ┆ weep-184   ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ a4qtqujv ┆ bumbling-s ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.693177  ┆ 0.693147  ┆ 0.001092  ┆ 0.005363  │
# │          ┆ weep-185   ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ cygum81i ┆ dandy-swee ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.045775  ┆ 0.230016  ┆ 0.022875  ┆ 0.088568  │
# │          ┆ p-186      ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ v8z6rnqh ┆ honest-swe ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.726931  ┆ 0.7571    ┆ 0.01289   ┆ 0.053317  │
# │          ┆ ep-187     ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ wa9n883f ┆ peach-swee ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.324807  ┆ 0.371537  ┆ 0.026115  ┆ 0.100347  │
# │          ┆ p-188      ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ 5j8iin5i ┆ cerulean-s ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.216872  ┆ 0.356222  ┆ 0.026413  ┆ 0.102487  │
# │          ┆ weep-189   ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ jf9185ux ┆ easy-sweep ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.07441   ┆ 0.176159  ┆ 0.02399   ┆ 0.094012  │
# │          ┆ -190       ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ s5f17655 ┆ hopeful-sw ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.725654  ┆ 0.729766  ┆ 0.000203  ┆ 0.00103   │
# │          ┆ eep-191    ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# │ 340x762d ┆ ethereal-s ┆ hff1uixt ┆ matrix_fa ┆ … ┆ 0.182888  ┆ 0.324263  ┆ 0.027446  ┆ 0.105871  │
# │          ┆ weep-192   ┆          ┆ ctorizati ┆   ┆           ┆           ┆           ┆           │
# │          ┆            ┆          ┆ on        ┆   ┆           ┆           ┆           ┆           │
# └──────────┴────────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# # High Level Parameter Comparison
# We pick one parameter and then see its impact on the overall performance, setting the other parameters to their best values.

# %% [markdown]
# ## Global Leaderboard

# %%
experiment_summary = experiment_runs.filter(
    # pl.col("shuffle") == False,
    # pl.col("embedding_dimension") == 64,
    # pl.col("l1_regularization") == 0.0,
    # pl.col("l2_regularization") == 0.0,
    # pl.col("embedding_dropout_rate") == 0.0
).group_by( # group over random_seed runs
    "shuffle", "embedding_dimension", "l2_regularization", "l1_regularization", "embedding_dropout_rate"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort(
    "best:epoch/test_recall@20", descending=True
).with_columns(
    pl.col("l1_regularization").cast(pl.Utf8),
    pl.col("l2_regularization").cast(pl.Utf8)
)
experiment_summary.to_pandas()
# Out:
#      shuffle  embedding_dimension l2_regularization l1_regularization  \
# 0      False                  128              1e-7              1e-7
# 1       True                  512              1e-7              1e-7
# 2      False                  256              1e-7              1e-7
# 3      False                  256              1e-7              1e-8
# 4       True                  128              1e-7              1e-7
# ..       ...                  ...               ...               ...
# 552     True                  128           0.00001           0.00001
# 553     True                  512            0.0001              1e-6
# 554    False                  128           0.00001           0.00001
# 555    False                  512            0.0001              1e-6
# 556    False                   64            0.0001              1e-6
#
#      embedding_dropout_rate  num_runs  best:epoch/epoch  \
# 0                         0         7         53.285714
# 1                         0         1         28.000000
# 2                         0         2         54.500000
# 3                         0         1         61.000000
# 4                         0         2         54.000000
# ..                      ...       ...               ...
# 552                       0         6          9.500000
# 553                       0         1          0.000000
# 554                       0         3          2.000000
# 555                       0         1          1.000000
# 556                       0         1          0.000000
#
#      best:epoch/test_recall@10  best:epoch/test_ndcg@10  \
# 0                     0.028866                 0.109814
# 1                     0.029088                 0.109141
# 2                     0.028998                 0.110754
# 3                     0.028682                 0.108945
# 4                     0.028584                 0.107302
# ..                         ...                      ...
# 552                   0.000227                 0.001042
# 553                   0.000210                 0.001027
# 554                   0.000211                 0.001040
# 555                   0.000203                 0.001030
# 556                   0.000201                 0.000968
#
#      best:epoch/test_recall@20  best:epoch/test_ndcg@20
# 0                     0.050247                 0.137913
# 1                     0.050239                 0.137186
# 2                     0.050139                 0.138627
# 3                     0.049684                 0.137072
# 4                     0.049522                 0.135343
# ..                         ...                      ...
# 552                   0.000466                 0.001649
# 553                   0.000458                 0.001626
# 554                   0.000440                 0.001603
# 555                   0.000424                 0.001650
# 556                   0.000414                 0.001559
#
# [557 rows x 11 columns]

# %% [markdown]
# ## Shuffle Impact

# %%
experiment_summary = experiment_runs.filter(
    # pl.col("shuffle") == False,
    # pl.col("embedding_dimension") == 64,
    # pl.col("l1_regularization") == 0.0,
    # pl.col("l2_regularization") == 0.0,
    # pl.col("embedding_dropout_rate") == 0.0
).group_by( # group over random_seed runs
    "shuffle", "embedding_dimension", "l2_regularization", "l1_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).group_by( # group over unrelevant parameters, e.g., regularization
    "shuffle", "embedding_dimension"
).agg(
    pl.col("num_runs").sum(),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").max(),
    pl.col("best:epoch/test_ndcg@10").max(),
    pl.col("best:epoch/test_recall@20").max(),
    pl.col("best:epoch/test_ndcg@20").max(),
).sort("shuffle", "embedding_dimension")

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["embedding_dimension", "shuffle", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="shuffle"
)
# Out:
# /tmp/ipykernel_2703953/3242880112.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "shuffle", "num_runs"]].pivot(
# shape: (10, 3)
# ┌─────────────────────┬───────┬──────┐
# │ embedding_dimension ┆ false ┆ true │
# │ ---                 ┆ ---   ┆ ---  │
# │ i64                 ┆ u32   ┆ u32  │
# ╞═════════════════════╪═══════╪══════╡
# │ 2                   ┆ 91    ┆ 88   │
# │ 4                   ┆ 86    ┆ 84   │
# │ 8                   ┆ 88    ┆ 82   │
# │ 16                  ┆ 82    ┆ 90   │
# │ 32                  ┆ 91    ┆ 90   │
# │ 64                  ┆ 92    ┆ 100  │
# │ 128                 ┆ 295   ┆ 350  │
# │ 256                 ┆ 112   ┆ 104  │
# │ 512                 ┆ 89    ┆ 116  │
# │ 1024                ┆ 104   ┆ 109  │
# └─────────────────────┴───────┴──────┘

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["embedding_dimension", "shuffle", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="embedding_dimension",
        on="shuffle"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_980c2_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_980c2_row0_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_980c2_row1_col0 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_980c2_row1_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_980c2_row2_col0 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_980c2_row2_col1 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_980c2_row3_col0, #T_980c2_row8_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_980c2_row3_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_980c2_row4_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_980c2_row4_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_980c2_row5_col0 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_980c2_row5_col1 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_980c2_row6_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_980c2_row6_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_980c2_row7_col0, #T_980c2_row7_col1, #T_980c2_row9_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_980c2_row8_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_980c2_row9_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_980c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_980c2_level0_col0" class="col_heading level0 col0" >false</th>
#       <th id="T_980c2_level0_col1" class="col_heading level0 col1" >true</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_980c2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_980c2_row0_col0" class="data row0 col0" >0.028021</td>
#       <td id="T_980c2_row0_col1" class="data row0 col1" >0.028110</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_980c2_row1_col0" class="data row1 col0" >0.036566</td>
#       <td id="T_980c2_row1_col1" class="data row1 col1" >0.036723</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_980c2_row2_col0" class="data row2 col0" >0.042089</td>
#       <td id="T_980c2_row2_col1" class="data row2 col1" >0.042581</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_980c2_row3_col0" class="data row3 col0" >0.045753</td>
#       <td id="T_980c2_row3_col1" class="data row3 col1" >0.046500</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_980c2_row4_col0" class="data row4 col0" >0.047913</td>
#       <td id="T_980c2_row4_col1" class="data row4 col1" >0.047524</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row5" class="row_heading level0 row5" >64</th>
#       <td id="T_980c2_row5_col0" class="data row5 col0" >0.048462</td>
#       <td id="T_980c2_row5_col1" class="data row5 col1" >0.048557</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_980c2_row6_col0" class="data row6 col0" >0.050247</td>
#       <td id="T_980c2_row6_col1" class="data row6 col1" >0.049522</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row7" class="row_heading level0 row7" >256</th>
#       <td id="T_980c2_row7_col0" class="data row7 col0" >0.047799</td>
#       <td id="T_980c2_row7_col1" class="data row7 col1" >0.047734</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row8" class="row_heading level0 row8" >512</th>
#       <td id="T_980c2_row8_col0" class="data row8 col0" >0.047714</td>
#       <td id="T_980c2_row8_col1" class="data row8 col1" >0.045771</td>
#     </tr>
#     <tr>
#       <th id="T_980c2_level0_row9" class="row_heading level0 row9" >1024</th>
#       <td id="T_980c2_row9_col0" class="data row9 col0" >0.047753</td>
#       <td id="T_980c2_row9_col1" class="data row9 col1" >0.046157</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["embedding_dimension", "shuffle", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="embedding_dimension",
        on="shuffle"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_17014_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_17014_row0_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_17014_row1_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_17014_row1_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_17014_row2_col0 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_17014_row2_col1 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_17014_row3_col0, #T_17014_row3_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_17014_row4_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_17014_row4_col1, #T_17014_row7_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_17014_row5_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_17014_row5_col1 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_17014_row6_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_17014_row6_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_17014_row7_col0 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_17014_row8_col0 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_17014_row8_col1 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_17014_row9_col0 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_17014_row9_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17014">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17014_level0_col0" class="col_heading level0 col0" >false</th>
#       <th id="T_17014_level0_col1" class="col_heading level0 col1" >true</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17014_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_17014_row0_col0" class="data row0 col0" >0.080881</td>
#       <td id="T_17014_row0_col1" class="data row0 col1" >0.081370</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_17014_row1_col0" class="data row1 col0" >0.102952</td>
#       <td id="T_17014_row1_col1" class="data row1 col1" >0.103918</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_17014_row2_col0" class="data row2 col0" >0.117660</td>
#       <td id="T_17014_row2_col1" class="data row2 col1" >0.119901</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_17014_row3_col0" class="data row3 col0" >0.128185</td>
#       <td id="T_17014_row3_col1" class="data row3 col1" >0.128256</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_17014_row4_col0" class="data row4 col0" >0.132597</td>
#       <td id="T_17014_row4_col1" class="data row4 col1" >0.131433</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row5" class="row_heading level0 row5" >64</th>
#       <td id="T_17014_row5_col0" class="data row5 col0" >0.134260</td>
#       <td id="T_17014_row5_col1" class="data row5 col1" >0.133791</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_17014_row6_col0" class="data row6 col0" >0.137913</td>
#       <td id="T_17014_row6_col1" class="data row6 col1" >0.136560</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row7" class="row_heading level0 row7" >256</th>
#       <td id="T_17014_row7_col0" class="data row7 col0" >0.132158</td>
#       <td id="T_17014_row7_col1" class="data row7 col1" >0.131401</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row8" class="row_heading level0 row8" >512</th>
#       <td id="T_17014_row8_col0" class="data row8 col0" >0.133339</td>
#       <td id="T_17014_row8_col1" class="data row8 col1" >0.127677</td>
#     </tr>
#     <tr>
#       <th id="T_17014_level0_row9" class="row_heading level0 row9" >1024</th>
#       <td id="T_17014_row9_col0" class="data row9 col0" >0.132359</td>
#       <td id="T_17014_row9_col1" class="data row9 col1" >0.128846</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Parameter Comparison Deep Dive
# Here we select only 2 free variables and fixed the rest to see what effect these two variable had

# %% [markdown]
# ## L2 Regularization, Shuffle = False, L1 = 0.0, Dropout = 0.0

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == False,
    pl.col("l1_regularization") == 0.0,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "embedding_dimension", "l2_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort("embedding_dimension", "l2_regularization")

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["embedding_dimension", "l2_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="l2_regularization"
)
# Out:
# /tmp/ipykernel_2703953/2842099446.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "l2_regularization", "num_runs"]].pivot(
# shape: (10, 11)
# ┌─────────────────────┬─────┬───────┬──────┬───┬─────────┬────────┬───────┬──────┐
# │ embedding_dimension ┆ 0.0 ┆ 1e-10 ┆ 1e-9 ┆ … ┆ 0.00001 ┆ 0.0001 ┆ 0.001 ┆ 0.01 │
# │ ---                 ┆ --- ┆ ---   ┆ ---  ┆   ┆ ---     ┆ ---    ┆ ---   ┆ ---  │
# │ i64                 ┆ u32 ┆ u32   ┆ u32  ┆   ┆ u32     ┆ u32    ┆ u32   ┆ u32  │
# ╞═════════════════════╪═════╪═══════╪══════╪═══╪═════════╪════════╪═══════╪══════╡
# │ 2                   ┆ 6   ┆ 4     ┆ 4    ┆ … ┆ 6       ┆ 4      ┆ 5     ┆ 6    │
# │ 4                   ┆ 9   ┆ 2     ┆ 4    ┆ … ┆ 4       ┆ 6      ┆ 4     ┆ 7    │
# │ 8                   ┆ 9   ┆ 9     ┆ 4    ┆ … ┆ 3       ┆ 4      ┆ 5     ┆ 3    │
# │ 16                  ┆ 8   ┆ 2     ┆ 2    ┆ … ┆ 3       ┆ 9      ┆ 4     ┆ 4    │
# │ 32                  ┆ 4   ┆ 3     ┆ 3    ┆ … ┆ 4       ┆ 6      ┆ 9     ┆ 8    │
# │ 64                  ┆ 6   ┆ 3     ┆ 3    ┆ … ┆ 4       ┆ 5      ┆ 5     ┆ 2    │
# │ 128                 ┆ 15  ┆ 2     ┆ 7    ┆ … ┆ 8       ┆ 6      ┆ 7     ┆ 3    │
# │ 256                 ┆ 10  ┆ 3     ┆ 4    ┆ … ┆ 5       ┆ 4      ┆ 5     ┆ 6    │
# │ 512                 ┆ 6   ┆ 2     ┆ 3    ┆ … ┆ 4       ┆ 7      ┆ 4     ┆ 4    │
# │ 1024                ┆ 8   ┆ 5     ┆ 2    ┆ … ┆ 5       ┆ 8      ┆ 3     ┆ 5    │
# └─────────────────────┴─────┴───────┴──────┴───┴─────────┴────────┴───────┴──────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_0c7d3_row0_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col2, #T_0c7d3_row7_col5 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col3, #T_0c7d3_row0_col4, #T_0c7d3_row7_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col5 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col6 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_0c7d3_row0_col7 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_0c7d3_row0_col8 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_0c7d3_row0_col9, #T_0c7d3_row2_col9, #T_0c7d3_row3_col9 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0c7d3_row1_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col4 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col5, #T_0c7d3_row4_col8, #T_0c7d3_row7_col8 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col6 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0c7d3_row1_col8, #T_0c7d3_row3_col8 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_0c7d3_row1_col9 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_0c7d3_row2_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col2 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col4, #T_0c7d3_row2_col6 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col5 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_0c7d3_row2_col7 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_0c7d3_row2_col8 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col1, #T_0c7d3_row4_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_0c7d3_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col4 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col5 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col6, #T_0c7d3_row7_col6 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_0c7d3_row3_col7, #T_0c7d3_row6_col7 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_0c7d3_row4_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_0c7d3_row4_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0c7d3_row4_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_0c7d3_row4_col4 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_0c7d3_row4_col5 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_0c7d3_row4_col6 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_0c7d3_row4_col7, #T_0c7d3_row7_col7, #T_0c7d3_row8_col7 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_0c7d3_row4_col9, #T_0c7d3_row5_col9, #T_0c7d3_row7_col9, #T_0c7d3_row8_col9 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_0c7d3_row5_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_0c7d3_row5_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0c7d3_row5_col2, #T_0c7d3_row6_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_0c7d3_row5_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_0c7d3_row5_col4 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_0c7d3_row5_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_0c7d3_row5_col6 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_0c7d3_row5_col7, #T_0c7d3_row9_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_0c7d3_row5_col8 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_0c7d3_row6_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0c7d3_row6_col2, #T_0c7d3_row7_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0c7d3_row6_col3, #T_0c7d3_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0c7d3_row6_col4 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_0c7d3_row6_col5 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_0c7d3_row6_col6, #T_0c7d3_row8_col6, #T_0c7d3_row8_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0c7d3_row6_col8 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_0c7d3_row6_col9 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_0c7d3_row7_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_0c7d3_row7_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0c7d3_row8_col0, #T_0c7d3_row8_col1, #T_0c7d3_row9_col0, #T_0c7d3_row9_col1, #T_0c7d3_row9_col2, #T_0c7d3_row9_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0c7d3_row8_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_0c7d3_row8_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0c7d3_row8_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_0c7d3_row8_col5 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_0c7d3_row9_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_0c7d3_row9_col5 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_0c7d3_row9_col6 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_0c7d3_row9_col8 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_0c7d3_row9_col9 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# </style>
# <table id="T_0c7d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c7d3_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_0c7d3_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_0c7d3_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_0c7d3_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_0c7d3_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_0c7d3_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_0c7d3_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_0c7d3_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_0c7d3_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_0c7d3_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c7d3_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0c7d3_row0_col0" class="data row0 col0" >52.00</td>
#       <td id="T_0c7d3_row0_col1" class="data row0 col1" >58.50</td>
#       <td id="T_0c7d3_row0_col2" class="data row0 col2" >49.25</td>
#       <td id="T_0c7d3_row0_col3" class="data row0 col3" >55.60</td>
#       <td id="T_0c7d3_row0_col4" class="data row0 col4" >55.60</td>
#       <td id="T_0c7d3_row0_col5" class="data row0 col5" >34.67</td>
#       <td id="T_0c7d3_row0_col6" class="data row0 col6" >56.50</td>
#       <td id="T_0c7d3_row0_col7" class="data row0 col7" >9.50</td>
#       <td id="T_0c7d3_row0_col8" class="data row0 col8" >11.60</td>
#       <td id="T_0c7d3_row0_col9" class="data row0 col9" >9.67</td>
#     </tr>
#     <tr>
#       <th id="T_0c7d3_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_0c7d3_row1_col0" class="data row1 col0" >42.67</td>
#       <td id="T_0c7d3_row1_col1" class="d

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_39950_row0_col0 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_39950_row0_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_39950_row0_col2 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_39950_row0_col3 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_39950_row0_col4 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_39950_row0_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_39950_row0_col6 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_39950_row0_col7, #T_39950_row1_col7, #T_39950_row3_col7, #T_39950_row4_col7, #T_39950_row5_col7, #T_39950_row6_col7, #T_39950_row7_col7, #T_39950_row8_col7 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_39950_row0_col8, #T_39950_row1_col8, #T_39950_row2_col8, #T_39950_row3_col8, #T_39950_row4_col8, #T_39950_row5_col8, #T_39950_row6_col8, #T_39950_row7_col8, #T_39950_row8_col8, #T_39950_row9_col8 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_39950_row0_col9, #T_39950_row3_col9 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_39950_row1_col0, #T_39950_row1_col3 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_39950_row1_col1, #T_39950_row1_col5 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_39950_row1_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_39950_row1_col4 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_39950_row1_col6 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_39950_row1_col9, #T_39950_row2_col9, #T_39950_row4_col9, #T_39950_row8_col9 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_39950_row2_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_39950_row2_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_39950_row2_col2, #T_39950_row6_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_39950_row2_col3 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_39950_row2_col4, #T_39950_row8_col1, #T_39950_row9_col0 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_39950_row2_col5, #T_39950_row6_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_39950_row2_col6 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_39950_row2_col7 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_39950_row3_col0, #T_39950_row5_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_39950_row3_col1, #T_39950_row3_col2 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_39950_row3_col3, #T_39950_row4_col3, #T_39950_row7_col1, #T_39950_row8_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_39950_row3_col4 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_39950_row3_col5 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_39950_row3_col6 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_39950_row4_col0, #T_39950_row4_col2, #T_39950_row8_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_39950_row4_col1, #T_39950_row5_col3, #T_39950_row8_col2 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_39950_row4_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_39950_row4_col5 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_39950_row4_col6 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_39950_row5_col1, #T_39950_row5_col2 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_39950_row5_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_39950_row5_col5, #T_39950_row6_col5, #T_39950_row7_col5 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_39950_row5_col6 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_39950_row5_col9, #T_39950_row9_col9 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_39950_row6_col1, #T_39950_row7_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_39950_row6_col3, #T_39950_row7_col2 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_39950_row6_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_39950_row6_col6 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_39950_row6_col9, #T_39950_row7_col9 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_39950_row7_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_39950_row7_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_39950_row7_col6 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_39950_row8_col4, #T_39950_row9_col5 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_39950_row8_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_39950_row8_col6 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_39950_row9_col1, #T_39950_row9_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_39950_row9_col2 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_39950_row9_col3 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_39950_row9_col6 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_39950_row9_col7 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_39950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39950_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_39950_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_39950_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_39950_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_39950_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_39950_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_39950_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_39950_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_39950_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_39950_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39950_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_39950_row0_col0" class="data row0 col0" >0.028021</td>
#       <td id="T_39950_row0_col1" class="data row0 col1" >0.027479</td>
#       <td id="T_39950_row0_col2" class="data row0 col2" >0.026413</td>
#       <td id="T_39950_row0_col3" class="data row0 col3" >0.027161</td>
#       <td id="T_39950_row0_col4" class="data row0 col4" >0.026745</td>
#       <td id="T_39950_row0_col5" class="data row0 col5" >0.025906</td>
#       <td id="T_39950_row0_col6" class="data row0 col6" >0.009413</td>
#       <td id="T_39950_row0_col7" class="data row0 col7" >0.004251</td>
#       <td id="T_39950_row0_col8" class="data row0 col8" >0.000714</td>
#       <td id="T_39950_row0_col9" class="data row0 col9" >0.001170</td>
#     </tr>
#     <tr>
#       <th id="T_39950_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_39950_row1_col0" class="data row1 col0" >0.035421</td>
#       <td id="T_39950_row1_col1" class="data row1 col1" >0.036021</td>
#       <td id="T_39950_row1_col2" class="data row1 col2" >0.034871</td>
#       <td id="T_39950_row1_col3" class="data row1 col3" >0.035595</td>
#       <td id="T_39950_row1_col4" class="data row1 col4" >0.036566</td>
#       <td id="T_39950_row1_col5" class="data row1 col5" >0.036103</td>
#       <td id="T_39950_row1_col6" class="data row1 col6" >0.010423</td>
#       <td id="T_39950_row1_col7" class="data row1 col7" >0.004288</td>
#       <td id="T_39950_row1_col8" class="data row1 col8" >0.000620</td>
#       <td id="T_39950_row1_col9" class="data row1 col9" >0.001387</td>
#     </tr>
#     <tr>
#       <th id="T_39950_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_39950_row2_col0" class="data row2 col0" >0.038919</td>

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_f3e2e_row0_col0 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_f3e2e_row0_col1, #T_f3e2e_row0_col3 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_f3e2e_row0_col2 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_f3e2e_row0_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_f3e2e_row0_col5 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_f3e2e_row0_col6 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_f3e2e_row0_col7 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_f3e2e_row0_col8, #T_f3e2e_row1_col8, #T_f3e2e_row2_col8, #T_f3e2e_row3_col8, #T_f3e2e_row4_col8, #T_f3e2e_row5_col8 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f3e2e_row0_col9 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_f3e2e_row1_col0 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_f3e2e_row1_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_f3e2e_row1_col2 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_f3e2e_row1_col3 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_f3e2e_row1_col4, #T_f3e2e_row1_col5 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_f3e2e_row1_col6, #T_f3e2e_row2_col6 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_f3e2e_row1_col7, #T_f3e2e_row4_col7, #T_f3e2e_row6_col7, #T_f3e2e_row7_col7, #T_f3e2e_row8_col7, #T_f3e2e_row9_col7 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_f3e2e_row1_col9, #T_f3e2e_row2_col9, #T_f3e2e_row8_col9 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col0 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col1 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col3, #T_f3e2e_row6_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col4, #T_f3e2e_row8_col1, #T_f3e2e_row9_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col5 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_f3e2e_row2_col7, #T_f3e2e_row3_col7, #T_f3e2e_row5_col7 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col0, #T_f3e2e_row5_col0, #T_f3e2e_row8_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col1, #T_f3e2e_row3_col2, #T_f3e2e_row4_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col3, #T_f3e2e_row4_col3, #T_f3e2e_row5_col2, #T_f3e2e_row5_col3, #T_f3e2e_row7_col1, #T_f3e2e_row8_col3 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col5 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_f3e2e_row3_col6 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_f3e2e_row3_col9 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_f3e2e_row4_col1, #T_f3e2e_row8_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_f3e2e_row4_col2 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_f3e2e_row4_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_f3e2e_row4_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_f3e2e_row4_col6 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_f3e2e_row4_col9, #T_f3e2e_row7_col9, #T_f3e2e_row9_col9 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_f3e2e_row5_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_f3e2e_row5_col4, #T_f3e2e_row6_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f3e2e_row5_col5, #T_f3e2e_row6_col5 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_f3e2e_row5_col6 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_f3e2e_row5_col9 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_f3e2e_row6_col1, #T_f3e2e_row7_col3, #T_f3e2e_row9_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_f3e2e_row6_col2, #T_f3e2e_row6_col3, #T_f3e2e_row7_col2 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_f3e2e_row6_col6 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_f3e2e_row6_col8, #T_f3e2e_row7_col8, #T_f3e2e_row8_col8, #T_f3e2e_row9_col8 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_f3e2e_row6_col9 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_f3e2e_row7_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_f3e2e_row7_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_f3e2e_row7_col5, #T_f3e2e_row8_col5 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_f3e2e_row7_col6 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_f3e2e_row8_col4 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_f3e2e_row8_col6 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_f3e2e_row9_col1, #T_f3e2e_row9_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_f3e2e_row9_col2 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_f3e2e_row9_col5 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_f3e2e_row9_col6 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# </style>
# <table id="T_f3e2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3e2e_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_f3e2e_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_f3e2e_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_f3e2e_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_f3e2e_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_f3e2e_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_f3e2e_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_f3e2e_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_f3e2e_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_f3e2e_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3e2e_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_f3e2e_row0_col0" class="data row0 col0" >0.080881</td>
#       <td id="T_f3e2e_row0_col1" class="data row0 col1" >0.079558</td>
#       <td id="T_f3e2e_row0_col2" class="data row0 col2" >0.075915</td>
#       <td id="T_f3e2e_row0_col3" class="data row0 col3" >0.079271</td>
#       <td id="T_f3e2e_row0_col4" class="data row0 col4" >0.077531</td>
#       <td id="T_f3e2e_row0_col5" class="data row0 col5" >0.075099</td>
#       <td id="T_f3e2e_row0_col6" class="data row0 col6" >0.030217</td>
#       <td id="T_f3e2e_row0_col7" class="data row0 col7" >0.014389</td>
#       <td id="T_f3e2e_row0_col8" class="data row0 col8" >0.002484</td>
#       <td id="T_f3e2e_row0_col9" class="data row0 col9" >0.003616</td>
#     </tr>
#     <tr>
#       <th id="T_f3e2e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_f3e2e_row1_col0" class="data row1 col0" >0.101048</td>
#       <td id="T_f3e2e_row1_col1" class="data row1 col1" >0.102500</td>
#       <td id="T_f3e2e_row1_col2" class="data row1 col2" >0.098071</td>
#       <td id="T_f3e2e_row1_col3" class="data row1 col3" >0.100571</td>
#       <td id="T_f3e2e_row1_col4" class="data row1 col4" >0.102822</td>
#       <td id="T_f3e2e_row1_col5" class="data row1 col5" >0.102952</td>
#       <td id="T_f3e2e_row1_col6" class="data row1 col6" >0.033224</td>
#       <td id="T_f3e2e_row1_col7" class="data row1 col7" >0.015206</td>
#       <td id="T_f3e2e_row1_col8" class="data row1 col8" >0.002254</td>
#       <td id="T_f3e2e_row1_col9" class="data row1 col9" >0.004341</td>
#     </tr>
#     <tr>
#       <th id="T_f3e2e_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_f3e2e_r

# %% [markdown]
# ## L2 Regularization, Shuffle = True, L1 = 0.0, Dropout = 0.0

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == True,
    pl.col("l1_regularization") == 0.0,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "embedding_dimension", "l2_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort("embedding_dimension", "l2_regularization")

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["embedding_dimension", "l2_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="l2_regularization"
)
# Out:
# /tmp/ipykernel_2703953/2842099446.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "l2_regularization", "num_runs"]].pivot(
# shape: (10, 11)
# ┌─────────────────────┬─────┬───────┬──────┬───┬─────────┬────────┬───────┬──────┐
# │ embedding_dimension ┆ 0.0 ┆ 1e-10 ┆ 1e-9 ┆ … ┆ 0.00001 ┆ 0.0001 ┆ 0.001 ┆ 0.01 │
# │ ---                 ┆ --- ┆ ---   ┆ ---  ┆   ┆ ---     ┆ ---    ┆ ---   ┆ ---  │
# │ i64                 ┆ u32 ┆ u32   ┆ u32  ┆   ┆ u32     ┆ u32    ┆ u32   ┆ u32  │
# ╞═════════════════════╪═════╪═══════╪══════╪═══╪═════════╪════════╪═══════╪══════╡
# │ 2                   ┆ 7   ┆ 3     ┆ 3    ┆ … ┆ 5       ┆ 3      ┆ 7     ┆ 4    │
# │ 4                   ┆ 7   ┆ 3     ┆ 5    ┆ … ┆ 5       ┆ 8      ┆ 5     ┆ 3    │
# │ 8                   ┆ 9   ┆ 4     ┆ 2    ┆ … ┆ 5       ┆ 5      ┆ 4     ┆ 7    │
# │ 16                  ┆ 8   ┆ 3     ┆ 2    ┆ … ┆ 9       ┆ 4      ┆ 5     ┆ 6    │
# │ 32                  ┆ 11  ┆ 2     ┆ 2    ┆ … ┆ 3       ┆ 3      ┆ 3     ┆ 7    │
# │ 64                  ┆ 6   ┆ 5     ┆ 5    ┆ … ┆ 4       ┆ 5      ┆ 4     ┆ 7    │
# │ 128                 ┆ 12  ┆ 3     ┆ 9    ┆ … ┆ 8       ┆ 10     ┆ 4     ┆ 4    │
# │ 256                 ┆ 8   ┆ 2     ┆ 2    ┆ … ┆ 3       ┆ 4      ┆ 3     ┆ 5    │
# │ 512                 ┆ 5   ┆ 3     ┆ 5    ┆ … ┆ 2       ┆ 2      ┆ 5     ┆ 7    │
# │ 1024                ┆ 6   ┆ 4     ┆ 6    ┆ … ┆ 6       ┆ 7      ┆ 3     ┆ 5    │
# └─────────────────────┴─────┴───────┴──────┴───┴─────────┴────────┴───────┴──────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_ee027_row0_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col1, #T_ee027_row1_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col2, #T_ee027_row4_col8, #T_ee027_row6_col8, #T_ee027_row7_col8 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col3, #T_ee027_row1_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col5, #T_ee027_row2_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col6 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col7, #T_ee027_row7_col7 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_ee027_row0_col8, #T_ee027_row9_col8 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_ee027_row0_col9, #T_ee027_row4_col9 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_ee027_row1_col0, #T_ee027_row7_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col1, #T_ee027_row3_col4 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col4 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col5, #T_ee027_row2_col4, #T_ee027_row8_col8 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col6 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col7, #T_ee027_row2_col9, #T_ee027_row6_col9 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_ee027_row1_col8 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_ee027_row1_col9 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_ee027_row2_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_ee027_row2_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_ee027_row2_col2, #T_ee027_row5_col8 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_ee027_row2_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_ee027_row2_col5, #T_ee027_row2_col8 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_ee027_row2_col7, #T_ee027_row7_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_ee027_row3_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col2 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col3, #T_ee027_row5_col5 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col5 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col6 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col7, #T_ee027_row7_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_ee027_row3_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ee027_row3_col9 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_ee027_row4_col0, #T_ee027_row4_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_ee027_row4_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_ee027_row4_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_ee027_row4_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_ee027_row4_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_ee027_row4_col6 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_ee027_row4_col7, #T_ee027_row9_col7 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_ee027_row5_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_ee027_row5_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ee027_row5_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_ee027_row5_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_ee027_row5_col4 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_ee027_row5_col6 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_ee027_row5_col7 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_ee027_row5_col9, #T_ee027_row8_col9, #T_ee027_row9_col9 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_ee027_row6_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_ee027_row6_col1, #T_ee027_row9_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_ee027_row6_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_ee027_row6_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ee027_row6_col4 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_ee027_row6_col5 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_ee027_row6_col6 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_ee027_row6_col7 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_ee027_row7_col2, #T_ee027_row8_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_ee027_row7_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_ee027_row7_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_ee027_row7_col6, #T_ee027_row8_col6, #T_ee027_row9_col0, #T_ee027_row9_col1, #T_ee027_row9_col2, #T_ee027_row9_col3, #T_ee027_row9_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ee027_row7_col9 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ee027_row8_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_ee027_row8_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ee027_row8_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_ee027_row8_col4 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_ee027_row8_col5 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_ee027_row8_col7 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_ee027_row9_col5 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee027">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee027_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_ee027_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_ee027_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_ee027_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_ee027_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_ee027_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_ee027_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_ee027_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_ee027_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_ee027_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee027_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ee027_row0_col0" class="data row0 col0" >49.43</td>
#       <td id="T_ee027_row0_col1" class="data row0 col1" >48.67</td>
#       <td id="T_ee027_row0_col2" class="data row0 col2" >61.67</td>
#       <td id="T_ee027_row0_col3" class="data row0 col3" >55.60</td>
#       <td id="T_ee027_row0_col4" class="data row0 col4" >52.67</td>
#       <td id="T_ee027_row0_col5" class="data row0 col5" >44.00</td>
#       <td id="T_ee027_row0_col6" class="data row0 col6" >45.60</td>
#       <td id="T_ee027_row0_col7" class="data row0 col7" >9.67</td>
#       <td id="T_ee027_row0_col8" class="data row0 col8" >58.57</td>
#       <td id="T_ee027_row0_col9" class="data row0 col9" >9.00</td>
#     </tr>
#     <tr>
#       <th id="T_ee027_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ee027_row1_col0" class="data row1 col0" >54.29</td>
#       <td id="T_ee027_row1_col1" class="data row1 col1" >60.67</td>
#       <td id="T_ee027_row1_col2" class="data row1 col2" >48.60</td>
#       <td id="T_ee027_row1_col3" class="data row1 col3" >55.50</td>
#       <td id="T_ee027_row1_col4" clas

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_d7d9c_row0_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_d7d9c_row0_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_d7d9c_row0_col2, #T_d7d9c_row0_col5 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_d7d9c_row0_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_d7d9c_row0_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_d7d9c_row0_col6 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_d7d9c_row0_col7, #T_d7d9c_row4_col7, #T_d7d9c_row5_col7, #T_d7d9c_row6_col7, #T_d7d9c_row7_col7, #T_d7d9c_row8_col7 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_d7d9c_row0_col8, #T_d7d9c_row0_col9, #T_d7d9c_row2_col8, #T_d7d9c_row2_col9, #T_d7d9c_row3_col9, #T_d7d9c_row6_col9, #T_d7d9c_row9_col9 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_d7d9c_row1_col0, #T_d7d9c_row1_col1, #T_d7d9c_row1_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_d7d9c_row1_col2, #T_d7d9c_row8_col0 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_d7d9c_row1_col3 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_d7d9c_row1_col4, #T_d7d9c_row8_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_d7d9c_row1_col6, #T_d7d9c_row3_col6, #T_d7d9c_row4_col6 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_d7d9c_row1_col7, #T_d7d9c_row2_col7, #T_d7d9c_row3_col7 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_d7d9c_row1_col8, #T_d7d9c_row3_col8, #T_d7d9c_row4_col8, #T_d7d9c_row4_col9, #T_d7d9c_row5_col8, #T_d7d9c_row7_col9, #T_d7d9c_row8_col9 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_d7d9c_row1_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col0, #T_d7d9c_row6_col1 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col3, #T_d7d9c_row3_col0, #T_d7d9c_row3_col2, #T_d7d9c_row4_col2, #T_d7d9c_row9_col4 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col4 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col5 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_d7d9c_row2_col6 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_d7d9c_row3_col1, #T_d7d9c_row4_col0 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_d7d9c_row3_col3 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_d7d9c_row3_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_d7d9c_row3_col5 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_d7d9c_row4_col1, #T_d7d9c_row6_col3 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_d7d9c_row4_col3 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_d7d9c_row4_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_d7d9c_row4_col5 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_d7d9c_row5_col0, #T_d7d9c_row5_col1, #T_d7d9c_row5_col2 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_d7d9c_row5_col3 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_d7d9c_row5_col4, #T_d7d9c_row6_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d7d9c_row5_col5, #T_d7d9c_row8_col5 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_d7d9c_row5_col6 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_d7d9c_row5_col9, #T_d7d9c_row6_col8, #T_d7d9c_row7_col8 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_d7d9c_row6_col0, #T_d7d9c_row7_col2 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_d7d9c_row6_col2 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_d7d9c_row6_col5, #T_d7d9c_row9_col5 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_d7d9c_row6_col6 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_d7d9c_row7_col0, #T_d7d9c_row7_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_d7d9c_row7_col3 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_d7d9c_row7_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_d7d9c_row7_col5 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_d7d9c_row7_col6 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_d7d9c_row8_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_d7d9c_row8_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_d7d9c_row8_col4 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_d7d9c_row8_col6 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_d7d9c_row8_col8 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_d7d9c_row9_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_d7d9c_row9_col1, #T_d7d9c_row9_col2 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_d7d9c_row9_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_d7d9c_row9_col6 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_d7d9c_row9_col7 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_d7d9c_row9_col8 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d7d9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7d9c_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_d7d9c_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_d7d9c_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_d7d9c_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_d7d9c_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_d7d9c_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_d7d9c_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_d7d9c_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_d7d9c_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_d7d9c_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7d9c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_d7d9c_row0_col0" class="data row0 col0" >0.026836</td>
#       <td id="T_d7d9c_row0_col1" class="data row0 col1" >0.027117</td>
#       <td id="T_d7d9c_row0_col2" class="data row0 col2" >0.026956</td>
#       <td id="T_d7d9c_row0_col3" class="data row0 col3" >0.027582</td>
#       <td id="T_d7d9c_row0_col4" class="data row0 col4" >0.027373</td>
#       <td id="T_d7d9c_row0_col5" class="data row0 col5" >0.027062</td>
#       <td id="T_d7d9c_row0_col6" class="data row0 col6" >0.022443</td>
#       <td id="T_d7d9c_row0_col7" class="data row0 col7" >0.004824</td>
#       <td id="T_d7d9c_row0_col8" class="data row0 col8" >0.001253</td>
#       <td id="T_d7d9c_row0_col9" class="data row0 col9" >0.001291</td>
#     </tr>
#     <tr>
#       <th id="T_d7d9c_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_d7d9c_row1_col0" class="data row1 col0" >0.034983</td>
#       <td id="T_d7d9c_row1_col1" class="data row1 col1" >0.035082</td>
#       <td id="T_d7d9c_row1_col2" class="data row1 col2" >0.035621</td>
#       <td id="T_d7d9c_row1_col3" class="data row1 col3" >0.035248</td>
#       <td id="T_d7d9c_row1_col4" class="data row1 col4" >0.036723</td>
#       <td id="T_d7d9c_row1_col5" class="data row1 col5" >0.035059</td>
#       <td id="T_d7d9c_row1_col6" class="data row1 col6" >0.023605</td>
#       <td id="T_d7d9c_row1_col7" class="data row1 col7" >0.004646</td>
#       <td id="T_d7d9c_row1_col8" class="data row1 col8" >0.001419</td>
#       <td id="T_d7d9c_row1_col9" class="data row1 col9" >0.001035</td>
#     </tr>
#     <tr>
#       <th id="T_d7d9c_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_d7d9c_r

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["embedding_dimension", "l2_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="embedding_dimension",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_97215_row0_col0 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_97215_row0_col1, #T_97215_row0_col3, #T_97215_row0_col4 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_97215_row0_col2, #T_97215_row0_col5 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_97215_row0_col6 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_97215_row0_col7, #T_97215_row1_col7, #T_97215_row3_col7, #T_97215_row4_col7, #T_97215_row5_col7, #T_97215_row6_col7, #T_97215_row7_col7, #T_97215_row8_col7 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_97215_row0_col8, #T_97215_row2_col8, #T_97215_row5_col9, #T_97215_row7_col9, #T_97215_row8_col9 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_97215_row0_col9, #T_97215_row3_col9, #T_97215_row4_col9, #T_97215_row9_col9 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_97215_row1_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_97215_row1_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_97215_row1_col2 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_97215_row1_col3 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_97215_row1_col4, #T_97215_row8_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_97215_row1_col5 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_97215_row1_col6 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_97215_row1_col8, #T_97215_row3_col8, #T_97215_row4_col8 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_97215_row1_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_97215_row2_col0, #T_97215_row2_col2, #T_97215_row6_col0, #T_97215_row7_col3, #T_97215_row9_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_97215_row2_col1, #T_97215_row6_col2 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_97215_row2_col3, #T_97215_row3_col1, #T_97215_row4_col0, #T_97215_row4_col1, #T_97215_row4_col2, #T_97215_row6_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_97215_row2_col4 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_97215_row2_col5 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_97215_row2_col6, #T_97215_row4_col6 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_97215_row2_col7 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_97215_row2_col9, #T_97215_row6_col9 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_97215_row3_col0, #T_97215_row9_col4 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_97215_row3_col2, #T_97215_row5_col0, #T_97215_row5_col2 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_97215_row3_col3 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_97215_row3_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_97215_row3_col5 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_97215_row3_col6 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_97215_row4_col3 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_97215_row4_col4, #T_97215_row7_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_97215_row4_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_97215_row5_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_97215_row5_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_97215_row5_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_97215_row5_col5 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_97215_row5_col6 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_97215_row5_col8, #T_97215_row6_col8 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_97215_row6_col1 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_97215_row6_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_97215_row6_col5, #T_97215_row7_col5, #T_97215_row8_col5, #T_97215_row9_col5 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_97215_row6_col6 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_97215_row7_col0, #T_97215_row7_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_97215_row7_col2 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_97215_row7_col6 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_97215_row7_col8 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_97215_row8_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_97215_row8_col1, #T_97215_row9_col0 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_97215_row8_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_97215_row8_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_97215_row8_col6 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_97215_row8_col8 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_97215_row9_col2, #T_97215_row9_col3 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_97215_row9_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_97215_row9_col7 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_97215_row9_col8 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_97215">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97215_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_97215_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_97215_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_97215_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_97215_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_97215_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_97215_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_97215_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_97215_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_97215_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97215_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_97215_row0_col0" class="data row0 col0" >0.078058</td>
#       <td id="T_97215_row0_col1" class="data row0 col1" >0.080488</td>
#       <td id="T_97215_row0_col2" class="data row0 col2" >0.078890</td>
#       <td id="T_97215_row0_col3" class="data row0 col3" >0.080168</td>
#       <td id="T_97215_row0_col4" class="data row0 col4" >0.080319</td>
#       <td id="T_97215_row0_col5" class="data row0 col5" >0.079099</td>
#       <td id="T_97215_row0_col6" class="data row0 col6" >0.066975</td>
#       <td id="T_97215_row0_col7" class="data row0 col7" >0.016931</td>
#       <td id="T_97215_row0_col8" class="data row0 col8" >0.005061</td>
#       <td id="T_97215_row0_col9" class="data row0 col9" >0.004804</td>
#     </tr>
#     <tr>
#       <th id="T_97215_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_97215_row1_col0" class="data row1 col0" >0.099938</td>
#       <td id="T_97215_row1_col1" class="data row1 col1" >0.099181</td>
#       <td id="T_97215_row1_col2" class="data row1 col2" >0.101943</td>
#       <td id="T_97215_row1_col3" class="data row1 col3" >0.100334</td>
#       <td id="T_97215_row1_col4" class="data row1 col4" >0.103918</td>
#       <td id="T_97215_row1_col5" class="data row1 col5" >0.101334</td>
#       <td id="T_97215_row1_col6" class="data row1 col6" >0.070803</td>
#       <td id="T_97215_row1_col7" class="data row1 col7" >0.016738</td>
#       <td id="T_97215_row1_col8" class="data row1 col8" >0.005597</td>
#       <td id="T_97215_row1_col9" class="data row1 col9" >0.003315</td>
#     </tr>
#     <tr>
#       <th id="T_97215_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_97215_r

# %% [markdown]
# ## L1 Regularizatio, Shuffle = False, L2 = 0.0, Dropout = 0.0

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == False,
    pl.col("l2_regularization") == 0.0,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "embedding_dimension", "l1_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort("embedding_dimension", "l1_regularization")

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["embedding_dimension", "l1_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="l1_regularization"
)
# Out:
# /tmp/ipykernel_2703953/219270696.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "l1_regularization", "num_runs"]].pivot(
# shape: (10, 11)
# ┌─────────────────────┬─────┬───────┬──────┬───┬─────────┬────────┬───────┬──────┐
# │ embedding_dimension ┆ 0.0 ┆ 1e-10 ┆ 1e-9 ┆ … ┆ 0.00001 ┆ 0.0001 ┆ 0.001 ┆ 0.01 │
# │ ---                 ┆ --- ┆ ---   ┆ ---  ┆   ┆ ---     ┆ ---    ┆ ---   ┆ ---  │
# │ i64                 ┆ u32 ┆ u32   ┆ u32  ┆   ┆ u32     ┆ u32    ┆ u32   ┆ u32  │
# ╞═════════════════════╪═════╪═══════╪══════╪═══╪═════════╪════════╪═══════╪══════╡
# │ 2                   ┆ 6   ┆ 3     ┆ 4    ┆ … ┆ 6       ┆ 3      ┆ 4     ┆ 7    │
# │ 4                   ┆ 9   ┆ 3     ┆ 3    ┆ … ┆ 4       ┆ 3      ┆ 5     ┆ 6    │
# │ 8                   ┆ 9   ┆ 3     ┆ 6    ┆ … ┆ 7       ┆ 3      ┆ 5     ┆ 3    │
# │ 16                  ┆ 8   ┆ 2     ┆ 5    ┆ … ┆ 4       ┆ 6      ┆ 4     ┆ 4    │
# │ 32                  ┆ 4   ┆ 5     ┆ 5    ┆ … ┆ 5       ┆ 5      ┆ 3     ┆ 4    │
# │ 64                  ┆ 6   ┆ 3     ┆ 2    ┆ … ┆ 3       ┆ 4      ┆ 4     ┆ 2    │
# │ 128                 ┆ 15  ┆ 3     ┆ 10   ┆ … ┆ 8       ┆ 5      ┆ 4     ┆ 3    │
# │ 256                 ┆ 10  ┆ 5     ┆ 3    ┆ … ┆ 5       ┆ 3      ┆ 7     ┆ 3    │
# │ 512                 ┆ 6   ┆ 2     ┆ 2    ┆ … ┆ 2       ┆ 2      ┆ 4     ┆ 5    │
# │ 1024                ┆ 8   ┆ 4     ┆ 7    ┆ … ┆ 5       ┆ 3      ┆ 5     ┆ 3    │
# └─────────────────────┴─────┴───────┴──────┴───┴─────────┴────────┴───────┴──────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_2a8d7_row0_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col1, #T_2a8d7_row2_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col2, #T_2a8d7_row8_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col4 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_2a8d7_row0_col6, #T_2a8d7_row1_col0, #T_2a8d7_row4_col4 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col7 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col8 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_2a8d7_row0_col9 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_2a8d7_row1_col1, #T_2a8d7_row1_col2 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col5 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col7, #T_2a8d7_row4_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_2a8d7_row1_col8 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_2a8d7_row1_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col5 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col6, #T_2a8d7_row3_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_2a8d7_row2_col7, #T_2a8d7_row7_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2a8d7_row2_col8 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_2a8d7_row2_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_2a8d7_row3_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_2a8d7_row3_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_2a8d7_row3_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_2a8d7_row3_col4 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_2a8d7_row3_col5 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_2a8d7_row3_col6 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_2a8d7_row3_col7, #T_2a8d7_row5_col0, #T_2a8d7_row5_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_2a8d7_row3_col8, #T_2a8d7_row7_col8 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_2a8d7_row3_col9 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_2a8d7_row4_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_2a8d7_row4_col1, #T_2a8d7_row9_col8 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_2a8d7_row4_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_2a8d7_row4_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_2a8d7_row4_col6 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_2a8d7_row4_col7, #T_2a8d7_row7_col0, #T_2a8d7_row8_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_2a8d7_row4_col8, #T_2a8d7_row7_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_2a8d7_row4_col9 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_2a8d7_row5_col1, #T_2a8d7_row6_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_2a8d7_row5_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_2a8d7_row5_col4 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_2a8d7_row5_col5 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_2a8d7_row5_col6, #T_2a8d7_row9_col6 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_2a8d7_row5_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_2a8d7_row5_col8 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_2a8d7_row5_col9 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_2a8d7_row6_col0, #T_2a8d7_row6_col3 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_2a8d7_row6_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_2a8d7_row6_col4, #T_2a8d7_row9_col9 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_2a8d7_row6_col5 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_2a8d7_row6_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_2a8d7_row6_col7 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_2a8d7_row6_col8 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_2a8d7_row6_col9 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_2a8d7_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_2a8d7_row7_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2a8d7_row7_col3 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_2a8d7_row7_col4 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_2a8d7_row7_col5 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_2a8d7_row7_col6 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_2a8d7_row8_col0, #T_2a8d7_row8_col1, #T_2a8d7_row8_col2, #T_2a8d7_row9_col0, #T_2a8d7_row9_col1, #T_2a8d7_row9_col2, #T_2a8d7_row9_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2a8d7_row8_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_2a8d7_row8_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_2a8d7_row8_col5 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_2a8d7_row8_col8 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_2a8d7_row8_col9 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_2a8d7_row9_col4 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_2a8d7_row9_col5 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_2a8d7_row9_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# </style>
# <table id="T_2a8d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a8d7_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_2a8d7_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_2a8d7_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_2a8d7_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_2a8d7_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_2a8d7_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_2a8d7_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_2a8d7_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_2a8d7_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_2a8d7_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a8d7_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_2a8d7_row0_col0" class="data row0 col0" >52.00</td>
#       <td id="T_2a8d7_row0_col1" class="data row0 col1" >62.00</td>
#       <td id="T_2a8d7_row0_col2" class="data row0 col2" >51.00</td>
#       <td id="T_2a8d7_row0_col3" class="data row0 col3" >59.67</td>
#       <td id="T_2a8d7_row0_col4" class="data row0 col4" >60.00</td>
#       <td id="T_2a8d7_row0_col5" class="data row0 col5" >26.83</td>
#       <td id="T_2a8d7_row0_col6" class="data row0 col6" >42.67</td>
#       <td id="T_2a8d7_row0_col7" class="data row0 col7" >34.67</td>
#       <td id="T_2a8d7_row0_col8" class="data row0 col8" >41.50</td>
#       <td id="T_2a8d7_row0_col9" class="data row0 col9" >13.29</td>
#     </tr>
#     <tr>
#       <th id="T_2a8d7_level0_row

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_8cfcf_row0_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_8cfcf_row0_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_8cfcf_row0_col2 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_8cfcf_row0_col3, #T_8cfcf_row0_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_8cfcf_row0_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_8cfcf_row0_col6, #T_8cfcf_row1_col5, #T_8cfcf_row2_col5, #T_8cfcf_row3_col5, #T_8cfcf_row4_col5, #T_8cfcf_row5_col5, #T_8cfcf_row6_col5, #T_8cfcf_row7_col5, #T_8cfcf_row8_col5, #T_8cfcf_row9_col5 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_8cfcf_row0_col7, #T_8cfcf_row0_col8, #T_8cfcf_row0_col9, #T_8cfcf_row1_col6, #T_8cfcf_row1_col7, #T_8cfcf_row1_col8, #T_8cfcf_row1_col9, #T_8cfcf_row2_col6, #T_8cfcf_row2_col7, #T_8cfcf_row2_col8, #T_8cfcf_row2_col9, #T_8cfcf_row3_col6, #T_8cfcf_row3_col7, #T_8cfcf_row3_col8, #T_8cfcf_row3_col9, #T_8cfcf_row4_col6, #T_8cfcf_row4_col7, #T_8cfcf_row4_col8, #T_8cfcf_row4_col9, #T_8cfcf_row5_col6, #T_8cfcf_row5_col7, #T_8cfcf_row5_col8, #T_8cfcf_row5_col9, #T_8cfcf_row6_col6, #T_8cfcf_row6_col7, #T_8cfcf_row6_col8, #T_8cfcf_row6_col9, #T_8cfcf_row7_col6, #T_8cfcf_row7_col7, #T_8cfcf_row7_col8, #T_8cfcf_row7_col9, #T_8cfcf_row8_col6, #T_8cfcf_row8_col7, #T_8cfcf_row8_col8, #T_8cfcf_row8_col9, #T_8cfcf_row9_col6, #T_8cfcf_row9_col7, #T_8cfcf_row9_col8, #T_8cfcf_row9_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8cfcf_row1_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_8cfcf_row1_col1, #T_8cfcf_row1_col2 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_8cfcf_row1_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_8cfcf_row1_col4 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_8cfcf_row2_col0 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_8cfcf_row2_col1 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_8cfcf_row2_col2 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_8cfcf_row2_col3, #T_8cfcf_row6_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_8cfcf_row2_col4 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_8cfcf_row3_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_8cfcf_row3_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_8cfcf_row3_col2, #T_8cfcf_row3_col3, #T_8cfcf_row4_col0, #T_8cfcf_row8_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_8cfcf_row3_col4, #T_8cfcf_row9_col2, #T_8cfcf_row9_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_8cfcf_row4_col1 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_8cfcf_row4_col2, #T_8cfcf_row7_col2, #T_8cfcf_row8_col3 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_8cfcf_row4_col3, #T_8cfcf_row5_col1, #T_8cfcf_row5_col3, #T_8cfcf_row6_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_8cfcf_row4_col4 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8cfcf_row5_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_8cfcf_row5_col2, #T_8cfcf_row8_col1 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_8cfcf_row5_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_8cfcf_row6_col2 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_8cfcf_row6_col3, #T_8cfcf_row9_col1 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_8cfcf_row6_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_8cfcf_row7_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_8cfcf_row7_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_8cfcf_row7_col3, #T_8cfcf_row8_col2, #T_8cfcf_row9_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_8cfcf_row7_col4 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_8cfcf_row8_col4, #T_8cfcf_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cfcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cfcf_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_8cfcf_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_8cfcf_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_8cfcf_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_8cfcf_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_8cfcf_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_8cfcf_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_8cfcf_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_8cfcf_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_8cfcf_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cfcf_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_8cfcf_row0_col0" class="data row0 col0" >0.028021</td>
#       <td id="T_8cfcf_row0_col1" class="data row0 col1" >0.026830</td>
#       <td id="T_8cfcf_row0_col2" class="data row0 col2" >0.027656</td>
#       <td id="T_8cfcf_row0_col3" class="data row0 col3" >0.026286</td>
#       <td id="T_8cfcf_row0_col4" class="data row0 col4" >0.026239</td>
#       <td id="T_8cfcf_row0_col5" class="data row0 col5" >0.000969</td>
#       <td id="T_8cfcf_row0_col6" class="data row0 col6" >0.000822</td>
#       <td id="T_8cfcf_row0_col7" class="data row0 col7" >0.000572</td>
#       <td id="T_8cfcf_row0_col8" class="data row0 col8" >0.000655</td>
#       <td id="T_8cfcf_row0_col9" class="data row0 col9" >0.000667</td>
#     </tr>
#     <tr>
#       <th id="T_8cfcf_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8cfcf_row1_col0" class="data row1 col0" >0.035421</td>
#       <td id="T_8cfcf_row1_col1" class="data row1 col1" >0.035640</td>
#       <td id="T_8cfcf_row1_col2" class="data row1 col2" >0.035632</td>
#       <td id="T_8cfcf_row1_col3" class="data row1 col3" >0.034933</td>
#       <td id="T_8cfcf_row1_col4" class="data row1 col4" >0.035129</td>
#       <td id="T_8cfcf_row1_col5" class="data row1 col5" >0.000856</td>
#       <td id="T_8cfcf_row1_col6" class="data row1 col6" >0.000714</td>
#       <td id="T_8cfcf_row1_col7" class="data row1 col7" >0.000601</td>
#       <td id="T_8cfcf_row1_col8" class="data row1 col8" >0.000606</td>
#       <td id="T_8cfcf_row1_col9" class="data row1 col9" >0.000657</td>
#     </tr>
#     <tr>
#       <th id="T_8cfcf_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_8cfcf_row2_col0" class="data row2 col0" >0.038919</td>
#       <td id="T_8cfcf_row2_col1" class="data row2 col1" >0.039391</td>
#       <td id="T_8cfcf_row2_col2" class="data row2 col2" >0.038882</td>
#       <td id="T_8cfcf_row2_col3" class="data row2 col3" >0.039266</td>
#       <td id="T_8cfcf_row2_col4" class="data row2 col4" >0.040239</td>
#       <td id="T_8cfcf_row2_col5" class="data row2 col5" >0.000835</td>
#       <td id="T_8cfcf_row2_col6" class="data row2 col6" >0.000679</td>
#       <td id="T_8cfcf_row2_col7" class="data row2 col7" >0.000590</td>
#       <td id="T_8cfcf_row2_col8" class="data row2 col8" >0.000629</td>
#       <td id="T_8cfcf_row2_col9" class="data row2 col9" >0.000630</td>
#     </tr>
#     <tr>
#       <th id="T_8cfcf_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_8cfcf_row3_col0" class="data row3 col0" >0.039954</td>
#       <td id="T_8cfcf_row3_col1" class="data row3 col1" >0.039759</td>
#       <td id="T_8cfcf_row3_col2" class="data row3 col2" >0.040462</td>
#       <td id="T_8cfcf_row3_col3" class="data row3 col3" >0.040408</td>
#       <td id="T_8cfcf_row3_col4" c

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_6c378_row0_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_6c378_row0_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_6c378_row0_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_6c378_row0_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_6c378_row0_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_6c378_row0_col5 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_6c378_row0_col6, #T_6c378_row1_col6, #T_6c378_row2_col6, #T_6c378_row3_col6, #T_6c378_row5_col6, #T_6c378_row6_col5, #T_6c378_row6_col6 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_6c378_row0_col7, #T_6c378_row0_col8, #T_6c378_row0_col9, #T_6c378_row1_col7, #T_6c378_row1_col8, #T_6c378_row1_col9, #T_6c378_row2_col7, #T_6c378_row2_col8, #T_6c378_row2_col9, #T_6c378_row3_col7, #T_6c378_row3_col8, #T_6c378_row3_col9, #T_6c378_row4_col6, #T_6c378_row4_col7, #T_6c378_row4_col8, #T_6c378_row4_col9, #T_6c378_row5_col7, #T_6c378_row5_col8, #T_6c378_row5_col9, #T_6c378_row6_col7, #T_6c378_row6_col8, #T_6c378_row6_col9, #T_6c378_row7_col6, #T_6c378_row7_col7, #T_6c378_row7_col8, #T_6c378_row7_col9, #T_6c378_row8_col6, #T_6c378_row8_col7, #T_6c378_row8_col8, #T_6c378_row8_col9, #T_6c378_row9_col6, #T_6c378_row9_col7, #T_6c378_row9_col8, #T_6c378_row9_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6c378_row1_col0, #T_6c378_row1_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_6c378_row1_col2 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_6c378_row1_col3, #T_6c378_row1_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_6c378_row1_col5, #T_6c378_row2_col5, #T_6c378_row3_col5, #T_6c378_row4_col5, #T_6c378_row5_col5, #T_6c378_row7_col5, #T_6c378_row8_col5, #T_6c378_row9_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_6c378_row2_col0 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_6c378_row2_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_6c378_row2_col2 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_6c378_row2_col3 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_6c378_row2_col4, #T_6c378_row3_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_6c378_row3_col0, #T_6c378_row8_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_6c378_row3_col2, #T_6c378_row4_col0 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_6c378_row3_col3 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_6c378_row3_col4 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_6c378_row4_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_6c378_row4_col2, #T_6c378_row4_col3, #T_6c378_row7_col1, #T_6c378_row7_col2, #T_6c378_row8_col2, #T_6c378_row8_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_6c378_row4_col4 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_6c378_row5_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_6c378_row5_col1, #T_6c378_row8_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_6c378_row5_col2 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_6c378_row5_col3, #T_6c378_row6_col1, #T_6c378_row6_col2, #T_6c378_row9_col0, #T_6c378_row9_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_6c378_row5_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_6c378_row6_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_6c378_row6_col3, #T_6c378_row9_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_6c378_row6_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_6c378_row7_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_6c378_row7_col3 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_6c378_row7_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_6c378_row8_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6c378_row9_col3 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_6c378_row9_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c378">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c378_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_6c378_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_6c378_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_6c378_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_6c378_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_6c378_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_6c378_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_6c378_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_6c378_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_6c378_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c378_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_6c378_row0_col0" class="data row0 col0" >0.080881</td>
#       <td id="T_6c378_row0_col1" class="data row0 col1" >0.076956</td>
#       <td id="T_6c378_row0_col2" class="data row0 col2" >0.079496</td>
#       <td id="T_6c378_row0_col3" class="data row0 col3" >0.075915</td>
#       <td id="T_6c378_row0_col4" class="data row0 col4" >0.076528</td>
#       <td id="T_6c378_row0_col5" class="data row0 col5" >0.003734</td>
#       <td id="T_6c378_row0_col6" class="data row0 col6" >0.002814</td>
#       <td id="T_6c378_row0_col7" class="data row0 col7" >0.002277</td>
#       <td id="T_6c378_row0_col8" class="data row0 col8" >0.002369</td>
#       <td id="T_6c378_row0_col9" class="data row0 col9" >0.002334</td>
#     </tr>
#     <tr>
#       <th id="T_6c378_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_6c378_row1_col0" class="data row1 col0" >0.101048</td>
#       <td id="T_6c378_row1_col1" class="data row1 col1" >0.101263</td>
#       <td id="T_6c378_row1_col2" class="data row1 col2" >0.100029</td>
#       <td id="T_6c378_row1_col3" class="data row1 col3" >0.099579</td>
#       <td id="T_6c378_row1_col4" class="data row1 col4" >0.099798</td>
#       <td id="T_6c378_row1_col5" class="data row1 col5" >0.003160</td>
#       <td id="T_6c378_row1_col6" class="data row1 col6" >0.002529</td>
#       <td id="T_6c378_row1_col7" class="data row1 col7" >0.002110</td>
#       <td id="T_6c378_row1_col8" class="data row1 col8" >0.002201</td>
#       <td id="T_6c378_row1_col9" class="data row1 col9" >0.002352</td>
#     </tr>
#     <tr>
#       <th id="T_6c378_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_6c378_row2_col0" class="data row2 col0" >0.110166</td>
#       <td id="T_6c378_row2_col1" class="data row2 col1" >0.111070</td>
#       <td id="T_6c378_row2_col2" class="data row2 col2" >0.110459</td>
#       <td id="T_6c378_row2_col3" class="data row2 col3" >0.111534</td>
#       <td id="T_6c378_row2_col4" class="data row2 col4" >0.112798</td>
#       <td id="T_6c378_row2_col5" class="data row2 col5" >0.003143</td>
#       <td id="T_6c378_row2_col6" class="data row2 col6" >0.002460</td>
#       <td id="T_6c378_row2_col7" class="data row2 col7" >0.002072</td>
#       <td id="T_6c378_row2_col8" class="data row2 col8" >0.002198</td>
#       <td id="T_6c378_row2_col9" class="data row2 col9" >0.002279</td>
#     </tr>
#     <tr>
#       <th id="T_6c378_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_6c378_row3_col0" class="data row3 col0" >0.112943</td>
#       <td id="T_6c378_row3_col1" class="data row3 col1" >0.112572</td>
#       <td id="T_6c378_row3

# %% [markdown]
# ## L1 Regularization | Shuffle = True

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == True,
    pl.col("l2_regularization") == 0.0,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "embedding_dimension", "l1_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort("embedding_dimension", "l1_regularization")

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["embedding_dimension", "l1_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="l1_regularization"
)
# Out:
# /tmp/ipykernel_2703953/219270696.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "l1_regularization", "num_runs"]].pivot(
# shape: (10, 11)
# ┌─────────────────────┬─────┬───────┬──────┬───┬─────────┬────────┬───────┬──────┐
# │ embedding_dimension ┆ 0.0 ┆ 1e-10 ┆ 1e-9 ┆ … ┆ 0.00001 ┆ 0.0001 ┆ 0.001 ┆ 0.01 │
# │ ---                 ┆ --- ┆ ---   ┆ ---  ┆   ┆ ---     ┆ ---    ┆ ---   ┆ ---  │
# │ i64                 ┆ u32 ┆ u32   ┆ u32  ┆   ┆ u32     ┆ u32    ┆ u32   ┆ u32  │
# ╞═════════════════════╪═════╪═══════╪══════╪═══╪═════════╪════════╪═══════╪══════╡
# │ 2                   ┆ 7   ┆ 3     ┆ 8    ┆ … ┆ 3       ┆ 3      ┆ 3     ┆ 7    │
# │ 4                   ┆ 7   ┆ 5     ┆ 4    ┆ … ┆ 3       ┆ 3      ┆ 3     ┆ 3    │
# │ 8                   ┆ 9   ┆ 3     ┆ 7    ┆ … ┆ 3       ┆ 3      ┆ 3     ┆ 3    │
# │ 16                  ┆ 8   ┆ 4     ┆ 6    ┆ … ┆ 2       ┆ 5      ┆ 3     ┆ 3    │
# │ 32                  ┆ 11  ┆ 3     ┆ 4    ┆ … ┆ 4       ┆ 4      ┆ 4     ┆ 5    │
# │ 64                  ┆ 6   ┆ 4     ┆ 4    ┆ … ┆ 4       ┆ 5      ┆ 6     ┆ 3    │
# │ 128                 ┆ 12  ┆ 3     ┆ 10   ┆ … ┆ 15      ┆ 7      ┆ 7     ┆ 4    │
# │ 256                 ┆ 8   ┆ 2     ┆ 6    ┆ … ┆ 5       ┆ 4      ┆ 5     ┆ 5    │
# │ 512                 ┆ 5   ┆ 6     ┆ 5    ┆ … ┆ 4       ┆ 6      ┆ 5     ┆ 4    │
# │ 1024                ┆ 6   ┆ 4     ┆ 6    ┆ … ┆ 3       ┆ 4      ┆ 3     ┆ 5    │
# └─────────────────────┴─────┴───────┴──────┴───┴─────────┴────────┴───────┴──────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_7ad6c_row0_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col1, #T_7ad6c_row1_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col4 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col5 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_7ad6c_row0_col6 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_7ad6c_row0_col7, #T_7ad6c_row7_col8 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_7ad6c_row0_col8 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_7ad6c_row0_col9 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col1, #T_7ad6c_row2_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col2, #T_7ad6c_row4_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col4 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col5, #T_7ad6c_row9_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7ad6c_row1_col6, #T_7ad6c_row3_col6 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col7 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_7ad6c_row1_col8 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_7ad6c_row1_col9, #T_7ad6c_row3_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col1, #T_7ad6c_row5_col6 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col3 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_7ad6c_row2_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7ad6c_row2_col8, #T_7ad6c_row7_col6 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_7ad6c_row2_col9, #T_7ad6c_row4_col0, #T_7ad6c_row7_col7 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_7ad6c_row3_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_7ad6c_row3_col1 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_7ad6c_row3_col3 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_7ad6c_row3_col4 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_7ad6c_row3_col5 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_7ad6c_row3_col7 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_7ad6c_row3_col8 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_7ad6c_row3_col9 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_7ad6c_row4_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_7ad6c_row4_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_7ad6c_row4_col3, #T_7ad6c_row5_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_7ad6c_row4_col5 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_7ad6c_row4_col6 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_7ad6c_row4_col7, #T_7ad6c_row6_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_7ad6c_row4_col8 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_7ad6c_row4_col9 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_7ad6c_row5_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7ad6c_row5_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7ad6c_row5_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_7ad6c_row5_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_7ad6c_row5_col4 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_7ad6c_row5_col5 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_7ad6c_row5_col7 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7ad6c_row5_col8 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_7ad6c_row6_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_7ad6c_row6_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_7ad6c_row6_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_7ad6c_row6_col4 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7ad6c_row6_col5 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_7ad6c_row6_col6 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_7ad6c_row6_col7 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7ad6c_row6_col8 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_7ad6c_row6_col9 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_7ad6c_row7_col0, #T_7ad6c_row8_col3, #T_7ad6c_row8_col7, #T_7ad6c_row9_col7 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_7ad6c_row7_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_7ad6c_row7_col2, #T_7ad6c_row8_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_7ad6c_row7_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_7ad6c_row7_col4, #T_7ad6c_row8_col4 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7ad6c_row7_col5 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_7ad6c_row7_col9 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_7ad6c_row8_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_7ad6c_row8_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_7ad6c_row8_col5 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_7ad6c_row8_col6 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_7ad6c_row8_col8 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_7ad6c_row8_col9 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_7ad6c_row9_col0, #T_7ad6c_row9_col2, #T_7ad6c_row9_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7ad6c_row9_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7ad6c_row9_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_7ad6c_row9_col6 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_7ad6c_row9_col8 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_7ad6c_row9_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ad6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ad6c_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_7ad6c_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_7ad6c_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_7ad6c_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_7ad6c_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_7ad6c_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_7ad6c_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_7ad6c_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_7ad6c_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_7ad6c_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ad6c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_7ad6c_row0_col0" class="data row0 col0" >49.43</td>
#       <td id="T_7ad6c_row0_col1" class="data row0 col1" >46.33</td>
#       <td id="T_7ad6c_row0_col2" class="data row0 col2" >56.88</td>
#       <td id="T_7ad6c_row0_col3" class="data row0 col3" >48.25</td>
#       <td id="T_7ad6c_row0_col4" class="data row0 col4" >58.25</td>
#       <td id="T_7ad6c_row0_col5" class="data row0 col5" >20.22</td>
#       <td id="T_7ad6c_row0_col6" class="data row0 col6" >45.67</td>

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_37c04_row0_col0 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_37c04_row0_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_37c04_row0_col2 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_37c04_row0_col3 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_37c04_row0_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_37c04_row0_col5 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_37c04_row0_col6, #T_37c04_row0_col9 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_37c04_row0_col7, #T_37c04_row0_col8, #T_37c04_row1_col6, #T_37c04_row1_col7, #T_37c04_row1_col8, #T_37c04_row1_col9, #T_37c04_row2_col6, #T_37c04_row2_col7, #T_37c04_row2_col8, #T_37c04_row2_col9, #T_37c04_row3_col6, #T_37c04_row3_col7, #T_37c04_row3_col8, #T_37c04_row3_col9, #T_37c04_row4_col6, #T_37c04_row4_col7, #T_37c04_row4_col8, #T_37c04_row4_col9, #T_37c04_row5_col6, #T_37c04_row5_col7, #T_37c04_row5_col8, #T_37c04_row5_col9, #T_37c04_row6_col6, #T_37c04_row6_col7, #T_37c04_row6_col8, #T_37c04_row6_col9, #T_37c04_row7_col6, #T_37c04_row7_col7, #T_37c04_row7_col8, #T_37c04_row7_col9, #T_37c04_row8_col6, #T_37c04_row8_col7, #T_37c04_row8_col8, #T_37c04_row8_col9, #T_37c04_row9_col6, #T_37c04_row9_col7, #T_37c04_row9_col8, #T_37c04_row9_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_37c04_row1_col0, #T_37c04_row9_col5 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_37c04_row1_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_37c04_row1_col2 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_37c04_row1_col3, #T_37c04_row5_col5 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_37c04_row1_col4, #T_37c04_row8_col1 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_37c04_row1_col5 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_37c04_row2_col0, #T_37c04_row2_col1, #T_37c04_row2_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_37c04_row2_col3 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_37c04_row2_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_37c04_row2_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_37c04_row3_col0, #T_37c04_row3_col3, #T_37c04_row6_col3 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_37c04_row3_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_37c04_row3_col2, #T_37c04_row4_col0, #T_37c04_row4_col1, #T_37c04_row4_col2, #T_37c04_row5_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_37c04_row3_col4 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_37c04_row3_col5 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_37c04_row4_col3 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_37c04_row4_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_37c04_row4_col5 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_37c04_row5_col0, #T_37c04_row5_col2, #T_37c04_row7_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_37c04_row5_col3 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_37c04_row5_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_37c04_row6_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_37c04_row6_col1, #T_37c04_row6_col2 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_37c04_row6_col4 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_37c04_row6_col5 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_37c04_row7_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_37c04_row7_col1, #T_37c04_row9_col3 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_37c04_row7_col2, #T_37c04_row9_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_37c04_row7_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_37c04_row7_col5 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_37c04_row8_col0 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_37c04_row8_col2 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_37c04_row8_col3 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_37c04_row8_col4 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_37c04_row8_col5 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_37c04_row9_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_37c04_row9_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_37c04_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_37c04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37c04_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_37c04_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_37c04_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_37c04_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_37c04_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_37c04_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_37c04_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_37c04_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_37c04_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_37c04_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37c04_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_37c04_row0_col0" class="data row0 col0" >0.026836</td>
#       <td id="T_37c04_row0_col1" class="data row0 col1" >0.028110</td>
#       <td id="T_37c04_row0_col2" class="data row0 col2" >0.026352</td>
#       <td id="T_37c04_row0_col3" class="data row0 col3" >0.027689</td>
#       <td id="T_37c04_row0_col4" class="data row0 col4" >0.026472</td>
#       <td id="T_37c04_row0_col5" class="data row0 col5" >0.009493</td>
#       <td id="T_37c04_row0_col6" class="data row0 col6" >0.000793</td>
#       <td id="T_37c04_row0_col7" class="data row0 col7" >0.000652</td>
#       <td id="T_37c04_row0_col8" class="data row0 col8" >0.000680</td>
#       <td id="T_37c04_row0_col9" class="data row0 col9" >0.000718</td>
#     </tr>
#     <tr>
#       <th id="T_37c04_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_37c04_row1_col0" class="data row1 col0" >0.034983</td>
#       <td id="T_37c04_row1_col1" class="data row1 col1" >0.034839</td>
#       <td id="T_37c04_row1_col2" class="data row1 col2" >0.034672</td>
#       <td id="T_37c04_row1_col3" class="data row1 col3" >0.034054</td>
#       <td id="T_37c04_row1_col4" class="data row1 col4" >0.035874</td>
#       <td id="T_37c04_row1_col5" class="data row1 col5" >0.008691</td>
#       <td id="T_37c04_row1_col6" class="data row1 col6" >0.000689</td>
#       <td id="T_37c04_row1_col7" class="data row1 col7" >0.000596</td>
#       <td id="T_37c04_row1_col8" class="data row1 col8" >0.000602</td>
#       <td id="T_37c04_row1_col9" class="data row1 col9" >0.000645</td>
#     </tr>
#     <tr>
#       <th id="T_37c04_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_37c04_row2_col0" class="data row2 col0" >0.038897</td>
#       <td id="T_37c04_row2_col1" class="data row2 col1" >0.038970</td>
#       <td id="T_37c04_row2_col2" class="data row2 col2" >0.038930</td>
#       <td id="T_37c04_row2_col3" class="data row2 col3" >0.039577</td>
#       <td id="T_37c04_row2_col4" class="data row2 col4" >0.040547</td>
#       <td id="T_37c04_row2_col5" class="data row2 col5" >0.023306</td>
#       <td id="T_37c04_row2_col6" class="data row2 col6" >0.000715</td>
#       <td id="T_37c04_row2_col7" class="data row2 col7" >0.000625</td>

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["embedding_dimension", "l1_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="embedding_dimension",
        on="l1_regularization"
    )
    .to_pandas()
    .set_index("embedding_dimension")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_ccc11_row0_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_ccc11_row0_col1 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_ccc11_row0_col2, #T_ccc11_row0_col4 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_ccc11_row0_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_ccc11_row0_col5 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_ccc11_row0_col6, #T_ccc11_row0_col8, #T_ccc11_row0_col9, #T_ccc11_row1_col6, #T_ccc11_row2_col6, #T_ccc11_row5_col6, #T_ccc11_row6_col6 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_ccc11_row0_col7, #T_ccc11_row1_col7, #T_ccc11_row1_col8, #T_ccc11_row1_col9, #T_ccc11_row2_col7, #T_ccc11_row2_col8, #T_ccc11_row2_col9, #T_ccc11_row3_col6, #T_ccc11_row3_col7, #T_ccc11_row3_col8, #T_ccc11_row3_col9, #T_ccc11_row4_col6, #T_ccc11_row4_col7, #T_ccc11_row4_col8, #T_ccc11_row4_col9, #T_ccc11_row5_col7, #T_ccc11_row5_col8, #T_ccc11_row5_col9, #T_ccc11_row6_col7, #T_ccc11_row6_col8, #T_ccc11_row6_col9, #T_ccc11_row7_col6, #T_ccc11_row7_col7, #T_ccc11_row7_col8, #T_ccc11_row7_col9, #T_ccc11_row8_col6, #T_ccc11_row8_col7, #T_ccc11_row8_col8, #T_ccc11_row8_col9, #T_ccc11_row9_col6, #T_ccc11_row9_col7, #T_ccc11_row9_col8, #T_ccc11_row9_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ccc11_row1_col0, #T_ccc11_row9_col5 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_ccc11_row1_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_ccc11_row1_col2, #T_ccc11_row1_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_ccc11_row1_col4 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_ccc11_row1_col5 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_ccc11_row2_col0, #T_ccc11_row2_col1, #T_ccc11_row6_col0, #T_ccc11_row6_col1 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_ccc11_row2_col2 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_ccc11_row2_col3, #T_ccc11_row5_col0, #T_ccc11_row5_col2, #T_ccc11_row7_col3 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_ccc11_row2_col4 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_ccc11_row2_col5 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_ccc11_row3_col0, #T_ccc11_row3_col1, #T_ccc11_row3_col2, #T_ccc11_row4_col0, #T_ccc11_row4_col1, #T_ccc11_row4_col2, #T_ccc11_row5_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_ccc11_row3_col3, #T_ccc11_row6_col3 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_ccc11_row3_col4 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_ccc11_row3_col5 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_ccc11_row4_col3, #T_ccc11_row5_col3 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_ccc11_row4_col4 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_ccc11_row4_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_ccc11_row5_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_ccc11_row5_col5, #T_ccc11_row7_col5 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_ccc11_row6_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_ccc11_row6_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_ccc11_row6_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_ccc11_row7_col0, #T_ccc11_row9_col0 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_ccc11_row7_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_ccc11_row7_col2 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_ccc11_row7_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_ccc11_row8_col0 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_ccc11_row8_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_ccc11_row8_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_ccc11_row8_col3, #T_ccc11_row9_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_ccc11_row8_col4 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_ccc11_row8_col5 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_ccc11_row9_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_ccc11_row9_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_ccc11_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ccc11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccc11_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_ccc11_level0_col1" class="col_heading level0 col1" >1e-10</th>
#       <th id="T_ccc11_level0_col2" class="col_heading level0 col2" >1e-9</th>
#       <th id="T_ccc11_level0_col3" class="col_heading level0 col3" >1e-8</th>
#       <th id="T_ccc11_level0_col4" class="col_heading level0 col4" >1e-7</th>
#       <th id="T_ccc11_level0_col5" class="col_heading level0 col5" >1e-6</th>
#       <th id="T_ccc11_level0_col6" class="col_heading level0 col6" >0.00001</th>
#       <th id="T_ccc11_level0_col7" class="col_heading level0 col7" >0.0001</th>
#       <th id="T_ccc11_level0_col8" class="col_heading level0 col8" >0.001</th>
#       <th id="T_ccc11_level0_col9" class="col_heading level0 col9" >0.01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embedding_dimension</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccc11_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ccc11_row0_col0" class="data row0 col0" >0.078058</td>
#       <td id="T_ccc11_row0_col1" class="data row0 col1" >0.081370</td>
#       <td id="T_ccc11_row0_col2" class="data row0 col2" >0.076123</td>
#       <td id="T_ccc11_row0_col3" class="data row0 col3" >0.080396</td>
#       <td id="T_ccc11_row0_col4" class="data row0 col4" >0.076008</td>
#       <td id="T_ccc11_row0_col5" class="data row0 col5" >0.028311</td>
#       <td id="T_ccc11_row0_col6" class="data row0 col6" >0.002840</td>
#       <td id="T_ccc11_row0_col7" class="data row0 col7" >0.002261</td>
#       <td id="T_ccc11_row0_col8" class="data row0 col8" >0.002593</td>
#       <td id="T_ccc11_row0_col9" class="data row0 col9" >0.002648</td>
#     </tr>
#     <tr>
#       <th id="T_ccc11_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ccc11_row1_col0" class="data row1 col0" >0.099938</td>
#       <td id="T_ccc11_row1_col1" class="data row1 col1" >0.099085</td>
#       <td id="T_ccc11_row1_col2" class="data row1 col2" >0.098540</td>
#       <td id="T_ccc11_row1_col3" class="data row1 col3" >0.098458</td>
#       <td id="T_ccc11_row1_col4" class="data row1 col4" >0.101107</td>
#       <td id="T_ccc11_row1_col5" class="data row1 col5" >0.027767</td>
#       <td id="T_ccc11_row1_col6" class="data row1 col6" >0.002588</td>
#       <td id="T_ccc11_row1_col7" class="data row1 col7" >0.002179</td>
#       <td id="T_ccc11_row1_col8" class="data row1 col8" >0.002109</td>
#       <td id="T_ccc11_row1_col9" class="data row1 col9" >0.002373</td>
#     </tr>
#     <tr>
#       <th id="T_ccc11_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_ccc11_row2_col0" class="data row2 col0" >0.109760</td>
#       <td id="T_ccc11_row2_col1" class="data row2 col1" >0.109884</td>
#       <td id="T_ccc11_row2_col2" class="data row2 col2" >0.110733</td>
#       <td id="T_ccc11_row2_col3" class="data row2 col3" >0.112334</td>
#       <td id="T_ccc11_row2_col4" class="data row2 col4" >0.114508</td>
#       <td id="T_ccc11_row2_col5" class="data row2 col5" >0.069098</td>
#       <td id="T_ccc11_row2_col6" class="data row2 col6" >0.002536</td>
#       <td id="T_ccc11_row2_col7" class="data row2 col7" >0.002041</td>
#       <td id="T_ccc11_row2_col8" class="data row2 col8" >0.002391</td>
#       <td id="T_ccc11_row2_col9" class="data row2 col9" >0.002208</td>
#     </tr>
#     <tr>
#       <th id="T_ccc11_level0_row3" class="ro

# %% [markdown]
# ## ElasticNet, D=128, Shuffle = False
# We want to further deep dive what will happen if we use both L1 and L2 (or better know as ElasticNet) at the same time on Matrix Factorization.

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == False,
    pl.col("embedding_dimension") == 128,
    pl.col("l1_regularization") != 1e-10, pl.col("l1_regularization") <= 1e-4,
    pl.col("l2_regularization") != 1e-10, pl.col("l2_regularization") <= 1e-4,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "l1_regularization", "l2_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort(
    "l1_regularization", "l2_regularization"
).with_columns(
    pl.col("l1_regularization").cast(pl.Utf8),
    pl.col("l2_regularization").cast(pl.Utf8)
)

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="l1_regularization",
    columns="l2_regularization"
)
# Out:
# /tmp/ipykernel_2703953/1305047977.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
# shape: (7, 8)
# ┌───────────────────┬─────┬──────┬──────┬──────┬──────┬─────────┬────────┐
# │ l1_regularization ┆ 0.0 ┆ 1e-9 ┆ 1e-8 ┆ 1e-7 ┆ 1e-6 ┆ 0.00001 ┆ 0.0001 │
# │ ---               ┆ --- ┆ ---  ┆ ---  ┆ ---  ┆ ---  ┆ ---     ┆ ---    │
# │ str               ┆ u32 ┆ u32  ┆ u32  ┆ u32  ┆ u32  ┆ u32     ┆ u32    │
# ╞═══════════════════╪═════╪══════╪══════╪══════╪══════╪═════════╪════════╡
# │ 0.0               ┆ 15  ┆ 7    ┆ 8    ┆ 13   ┆ 8    ┆ 8       ┆ 6      │
# │ 1e-9              ┆ 10  ┆ 3    ┆ 5    ┆ 3    ┆ 2    ┆ 4       ┆ 8      │
# │ 1e-8              ┆ 5   ┆ 3    ┆ 2    ┆ 5    ┆ 6    ┆ 11      ┆ 3      │
# │ 1e-7              ┆ 10  ┆ 3    ┆ 5    ┆ 7    ┆ 6    ┆ 7       ┆ 5      │
# │ 1e-6              ┆ 6   ┆ 3    ┆ 2    ┆ 2    ┆ 6    ┆ 4       ┆ 2      │
# │ 0.00001           ┆ 8   ┆ 2    ┆ 3    ┆ 6    ┆ 4    ┆ 3       ┆ 6      │
# │ 0.0001            ┆ 5   ┆ 7    ┆ 4    ┆ 3    ┆ 7    ┆ 5       ┆ 7      │
# └───────────────────┴─────┴──────┴──────┴──────┴──────┴─────────┴────────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_84444_row0_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_84444_row0_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_84444_row0_col2, #T_84444_row1_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_84444_row0_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_84444_row0_col4 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_84444_row0_col5, #T_84444_row2_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_84444_row0_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_84444_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_84444_row1_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_84444_row1_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_84444_row1_col4 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_84444_row1_col5, #T_84444_row1_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_84444_row2_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_84444_row2_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_84444_row2_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_84444_row2_col3 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_84444_row2_col4 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_84444_row2_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_84444_row3_col0, #T_84444_row3_col1, #T_84444_row4_col5 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_84444_row3_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_84444_row3_col3, #T_84444_row3_col4 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_84444_row3_col5 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_84444_row3_col6, #T_84444_row5_col3 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_84444_row4_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_84444_row4_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_84444_row4_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_84444_row4_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_84444_row4_col4 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_84444_row4_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_84444_row5_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_84444_row5_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_84444_row5_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_84444_row5_col4 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_84444_row5_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_84444_row5_col6, #T_84444_row6_col6 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_84444_row6_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_84444_row6_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_84444_row6_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_84444_row6_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_84444_row6_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_84444_row6_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# </style>
# <table id="T_84444">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84444_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_84444_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_84444_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_84444_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_84444_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_84444_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_84444_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84444_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_84444_row0_col0" class="data row0 col0" >7.27</td>
#       <td id="T_84444_row0_col1" class="data row0 col1" >4.00</td>
#       <td id="T_84444_row0_col2" class="data row0 col2" >4.62</td>
#       <td id="T_84444_row0_col3" class="data row0 col3" >55.54</td>
#       <td id="T_84444_row0_col4" class="data row0 col4" >51.50</td>
#       <td id="T_84444_row0_col5" class="data row0 col5" >62.12</td>
#       <td id="T_84444_row0_col6" class="data row0 col6" >6.17</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_84444_row1_col0" class="data row1 col0" >4.50</td>
#       <td id="T_84444_row1_col1" class="data row1 col1" >3.00</td>
#       <td id="T_84444_row1_col2" class="data row1 col2" >5.60</td>
#       <td id="T_84444_row1_col3" class="data row1 col3" >58.33</td>
#       <td id="T_84444_row1_col4" class="data row1 col4" >50.00</td>
#       <td id="T_84444_row1_col5" class="data row1 col5" >1.00</td>
#       <td id="T_84444_row1_col6" class="data row1 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_84444_row2_col0" class="data row2 col0" >7.40</td>
#       <td id="T_84444_row2_col1" class="data row2 col1" >6.00</td>
#       <td id="T_84444_row2_col2" class="data row2 col2" >10.00</td>
#       <td id="T_84444_row2_col3" class="data row2 col3" >57.00</td>
#       <td id="T_84444_row2_col4" class="data row2 col4" >54.67</td>
#       <td id="T_84444_row2_col5" class="data row2 col5" >5.27</td>
#       <td id="T_84444_row2_col6" class="data row2 col6" >62.33</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_84444_row3_col0" class="data row3 col0" >27.60</td>
#       <td id="T_84444_row3_col1" class="data row3 col1" >27.67</td>
#       <td id="T_84444_row3_col2" class="data row3 col2" >32.20</td>
#       <td id="T_84444_row3_col3" class="data row3 col3" >53.29</td>
#       <td id="T_84444_row3_col4" class="data row3 col4" >53.17</td>
#       <td id="T_84444_row3_col5" class="data row3 col5" >39.71</td>
#       <td id="T_84444_row3_col6" class="data row3 col6" >42.00</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_84444_row4_col0" class="data row4 col0" >29.50</td>
#       <td id="T_84444_row4_col1" class="data row4 col1" >22.33</td>
#       <td id="T_84444_row4_col2" class="data row4 col2" >38.00</td>
#       <td id="T_84444_row4_col3" class="data row4 col3" >43.00</td>
#       <td id="T_84444_row4_col4" class="data row4 col4" >40.83</td>
#       <td id="T_84444_row4_col5" class="data row4 col5" >27.75</td>
#       <td id="T_84444_row4_col6" class="data row4 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_84444_row5_col0" class="data row5 col0" >41.62</td>
#       <td id="T_84444_row5_col1" class="data row5 col1" >40.00</td>
#       <td id="T_84444_row5_col2" class="data row5 col2" >45.00</td>
#       <td id="T_84444_row5_col3" class="data row5 col3" >42.00</td>
#       <td id="T_84444_row5_col4" class="data row5 col4" >49.50</td>
#       <td id="T_84444_row5_col5" class="data row5 col5" >2.00</td>
#       <td id="T_84444_row5_col6" class="data row5 col6" >40.50</td>
#     </tr>
#     <tr>
#       <th id="T_84444_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_84444_row6_col0" class="data row6 col0" >15.80</td>
#       <td id="T_84444_row6_col1" class="data row6 col1" >14.00</td>
#       <td id="T_84444_row6_col2" class="data row6 col2" >16.75</td>
#       <td id="T_84444_row6_col3" class="data row6 col3" >29.33</td>
#       <td id="T_84444_row6_col4" class="data row6 col4" >9.86</td>
#       <td id="T_84444_row6_col5" class="data

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_8b676_row0_col0 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_8b676_row0_col1, #T_8b676_row1_col0, #T_8b676_row1_col2 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_8b676_row0_col2 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_8b676_row0_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_8b676_row0_col4, #T_8b676_row1_col4, #T_8b676_row2_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_8b676_row0_col5 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_8b676_row0_col6 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_8b676_row1_col1, #T_8b676_row2_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_8b676_row1_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_8b676_row1_col5 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_8b676_row1_col6 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_8b676_row2_col0, #T_8b676_row2_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_8b676_row2_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_8b676_row2_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_8b676_row2_col6 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col5 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_8b676_row3_col6 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_8b676_row4_col0, #T_8b676_row4_col1, #T_8b676_row4_col2, #T_8b676_row4_col3, #T_8b676_row4_col5, #T_8b676_row5_col0, #T_8b676_row5_col1, #T_8b676_row5_col2, #T_8b676_row5_col3, #T_8b676_row5_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_8b676_row4_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_8b676_row4_col6, #T_8b676_row5_col5, #T_8b676_row5_col6, #T_8b676_row6_col0, #T_8b676_row6_col1, #T_8b676_row6_col2, #T_8b676_row6_col3, #T_8b676_row6_col4, #T_8b676_row6_col5, #T_8b676_row6_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b676_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_8b676_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_8b676_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_8b676_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_8b676_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_8b676_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_8b676_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b676_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_8b676_row0_col0" class="data row0 col0" >0.039105</td>
#       <td id="T_8b676_row0_col1" class="data row0 col1" >0.041816</td>
#       <td id="T_8b676_row0_col2" class="data row0 col2" >0.041981</td>
#       <td id="T_8b676_row0_col3" class="data row0 col3" >0.048783</td>
#       <td id="T_8b676_row0_col4" class="data row0 col4" >0.045145</td>
#       <td id="T_8b676_row0_col5" class="data row0 col5" >0.013157</td>
#       <td id="T_8b676_row0_col6" class="data row0 col6" >0.004336</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_8b676_row1_col0" class="data row1 col0" >0.041862</td>
#       <td id="T_8b676_row1_col1" class="data row1 col1" >0.042282</td>
#       <td id="T_8b676_row1_col2" class="data row1 col2" >0.041881</td>
#       <td id="T_8b676_row1_col3" class="data row1 col3" >0.049284</td>
#       <td id="T_8b676_row1_col4" class="data row1 col4" >0.045172</td>
#       <td id="T_8b676_row1_col5" class="data row1 col5" >0.008330</td>
#       <td id="T_8b676_row1_col6" class="data row1 col6" >0.001840</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_8b676_row2_col0" class="data row2 col0" >0.042525</td>
#       <td id="T_8b676_row2_col1" class="data row2 col1" >0.042375</td>
#       <td id="T_8b676_row2_col2" class="data row2 col2" >0.042587</td>
#       <td id="T_8b676_row2_col3" class="data row2 col3" >0.049477</td>
#       <td id="T_8b676_row2_col4" class="data row2 col4" >0.045104</td>
#       <td id="T_8b676_row2_col5" class="data row2 col5" >0.007187</td>
#       <td id="T_8b676_row2_col6" class="data row2 col6" >0.002129</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_8b676_row3_col0" class="data row3 col0" >0.046673</td>
#       <td id="T_8b676_row3_col1" class="data row3 col1" >0.046121</td>
#       <td id="T_8b676_row3_col2" class="data row3 col2" >0.047049</td>
#       <td id="T_8b676_row3_col3" class="data row3 col3" >0.050247</td>
#       <td id="T_8b676_row3_col4" class="data row3 col4" >0.044102</td>
#       <td id="T_8b676_row3_col5" class="data row3 col5" >0.002697</td>
#       <td id="T_8b676_row3_col6" class="data row3 col6" >0.004949</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_8b676_row4_col0" class="data row4 col0" >0.000802</td>
#       <td id="T_8b676_row4_col1" class="data row4 col1" >0.000807</td>
#       <td id="T_8b676_row4_col2" class="data row4 col2" >0.000821</td>
#       <td id="T_8b676_row4_col3" class="data row4 col3" >0.000773</td>
#       <td id="T_8b676_row4_col4" class="data row4 col4" >0.000874</td>
#       <td id="T_8b676_row4_col5" class="data row4 col5" >0.000810</td>
#       <td id="T_8b676_row4_col6" class="data row4 col6" >0.000466</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_8b676_row5_col0" class="data row5 col0" >0.000701</td>
#       <td id="T_8b676_row5_col1" class="data row5 col1" >0.000655</td>
#       <td id="T_8b676_row5_col2" class="data row5 col2" >0.000697</td>
#       <td id="T_8b676_row5_col3" class="data row5 col3" >0.000664</td>
#       <td id="T_8b676_row5_col4" class="data row5 col4" >0.000643</td>
#       <td id="T_8b676_row5_col5" class="data row5 col5" >0.000440</td>
#       <td id="T_8b676_row5_col6" class="data row5 col6" >0.000555</td>
#     </tr>
#     <tr>
#       <th id="T_8b676_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_8b676_row6_col0" class="data row6 col0" >0.000554</td>
#       <td id="T_8b676_row6_col1" class="data row6 col1" >0.000548</td>
#       <td id="T_8b676_row6_col2" class="data row6 col2" >0.000550</td>
#       <td id="T_8b676_row6_col3" class="data row6 col3" >0.000559</td>
#       <td id="T_8b676_row6_col4" class="data row6 col4" >0.000552</td>
#       <td id="T_8b676_row6_col5" class="data row6 col5" >0.000612</td>
#       <td id="T_8b676_row6_col6" class="data row6 col6" >0.000622</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_e0daa_row0_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_e0daa_row0_col1, #T_e0daa_row0_col2, #T_e0daa_row1_col1, #T_e0daa_row1_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_e0daa_row0_col3 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_e0daa_row0_col4, #T_e0daa_row2_col4 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_e0daa_row0_col5 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_e0daa_row0_col6 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_e0daa_row1_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_e0daa_row1_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_e0daa_row1_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_e0daa_row1_col5 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_e0daa_row1_col6 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_e0daa_row2_col0, #T_e0daa_row2_col2 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_e0daa_row2_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_e0daa_row2_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_e0daa_row2_col5 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_e0daa_row2_col6 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col0, #T_e0daa_row3_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col5 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col6 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_e0daa_row4_col0, #T_e0daa_row4_col1, #T_e0daa_row4_col2, #T_e0daa_row4_col3, #T_e0daa_row4_col4, #T_e0daa_row4_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_e0daa_row4_col6, #T_e0daa_row5_col5, #T_e0daa_row5_col6, #T_e0daa_row6_col0, #T_e0daa_row6_col1, #T_e0daa_row6_col2, #T_e0daa_row6_col3, #T_e0daa_row6_col4, #T_e0daa_row6_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e0daa_row5_col0, #T_e0daa_row5_col1, #T_e0daa_row5_col2, #T_e0daa_row5_col3, #T_e0daa_row5_col4, #T_e0daa_row6_col6 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e0daa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0daa_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_e0daa_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_e0daa_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_e0daa_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_e0daa_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_e0daa_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_e0daa_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0daa_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_e0daa_row0_col0" class="data row0 col0" >0.112180</td>
#       <td id="T_e0daa_row0_col1" class="data row0 col1" >0.118182</td>
#       <td id="T_e0daa_row0_col2" class="data row0 col2" >0.118205</td>
#       <td id="T_e0daa_row0_col3" class="data row0 col3" >0.134612</td>
#       <td id="T_e0daa_row0_col4" class="data row0 col4" >0.126499</td>
#       <td id="T_e0daa_row0_col5" class="data row0 col5" >0.040775</td>
#       <td id="T_e0daa_row0_col6" class="data row0 col6" >0.015099</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_e0daa_row1_col0" class="data row1 col0" >0.117561</td>
#       <td id="T_e0daa_row1_col1" class="data row1 col1" >0.118150</td>
#       <td id="T_e0daa_row1_col2" class="data row1 col2" >0.118094</td>
#       <td id="T_e0daa_row1_col3" class="data row1 col3" >0.135038</td>
#       <td id="T_e0daa_row1_col4" class="data row1 col4" >0.127528</td>
#       <td id="T_e0daa_row1_col5" class="data row1 col5" >0.027658</td>
#       <td id="T_e0daa_row1_col6" class="data row1 col6" >0.007161</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_e0daa_row2_col0" class="data row2 col0" >0.119577</td>
#       <td id="T_e0daa_row2_col1" class="data row2 col1" >0.119827</td>
#       <td id="T_e0daa_row2_col2" class="data row2 col2" >0.119294</td>
#       <td id="T_e0daa_row2_col3" class="data row2 col3" >0.136078</td>
#       <td id="T_e0daa_row2_col4" class="data row2 col4" >0.126447</td>
#       <td id="T_e0daa_row2_col5" class="data row2 col5" >0.024030</td>
#       <td id="T_e0daa_row2_col6" class="data row2 col6" >0.009092</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_e0daa_row3_col0" class="data row3 col0" >0.130190</td>
#       <td id="T_e0daa_row3_col1" class="data row3 col1" >0.128751</td>
#       <td id="T_e0daa_row3_col2" class="data row3 col2" >0.130131</td>
#       <td id="T_e0daa_row3_col3" class="data row3 col3" >0.137913</td>
#       <td id="T_e0daa_row3_col4" class="data row3 col4" >0.123769</td>
#       <td id="T_e0daa_row3_col5" class="data row3 col5" >0.010571</td>
#       <td id="T_e0daa_row3_col6" class="data row3 col6" >0.020474</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_e0daa_row4_col0" class="data row4 col0" >0.002912</td>
#       <td id="T_e0daa_row4_col1" class="data row4 col1" >0.003022</td>
#       <td id="T_e0daa_row4_col2" class="data row4 col2" >0.003037</td>
#       <td id="T_e0daa_row4_col3" class="data row4 col3" >0.003022</td>
#       <td id="T_e0daa_row4_col4" class="data row4 col4" >0.003115</td>
#       <td id="T_e0daa_row4_col5" class="data row4 col5" >0.003007</td>
#       <td id="T_e0daa_row4_col6" class="data row4 col6" >0.001618</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_e0daa_row5_col0" class="data row5 col0" >0.002493</td>
#       <td id="T_e0daa_row5_col1" class="data row5 col1" >0.002317</td>
#       <td id="T_e0daa_row5_col2" class="data row5 col2" >0.002360</td>
#       <td id="T_e0daa_row5_col3" class="data row5 col3" >0.002339</td>
#       <td id="T_e0daa_row5_col4" class="data row5 col4" >0.002446</td>
#       <td id="T_e0daa_row5_col5" class="data row5 col5" >0.001603</td>
#       <td id="T_e0daa_row5_col6" class="data row5 col6" >0.002047</td>
#     </tr>
#     <tr>
#       <th id="T_e0daa_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_e0daa_row6_col0" class="data row6 col0" >0.002050</td>
#       <td id="T_e0daa_row6_col1" class="data row6 col1" >0.002029</td>
#       <td id="T_e0daa_row6_col2" class="data row6 col2" >0.001982</td>
#       <td id="T_e0daa_row6_col3" class="data row6 col3" >0.002047</td>
#       <td id="T_e0daa_row6_col4" class="data row6 col4" >0.002009</td>
#       <td id="T_e0daa_row6_col5" class="data row6 col5" >0.002090</td>
#       <td id="T_e0daa_row6_col6" class="data row6 col6" >0.002220</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## ElasticNet, D=128, Shuffle = True
# We want to further deep dive what will happen if we use both L1 and L2 (or better know as ElasticNet) at the same time on Matrix Factorization.

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == True,
    pl.col("embedding_dimension") == 128,
    pl.col("l1_regularization") != 1e-10, pl.col("l1_regularization") <= 1e-4,
    pl.col("l2_regularization") != 1e-10, pl.col("l2_regularization") <= 1e-4,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "l1_regularization", "l2_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort(
    "l1_regularization", "l2_regularization"
).with_columns(
    pl.col("l1_regularization").cast(pl.Utf8),
    pl.col("l2_regularization").cast(pl.Utf8)
)
experiment_summary
# Out:
# shape: (49, 8)
# ┌────────────┬────────────┬──────────┬────────────┬────────────┬───────────┬───────────┬───────────┐
# │ l1_regular ┆ l2_regular ┆ num_runs ┆ best:epoch ┆ best:epoch ┆ best:epoc ┆ best:epoc ┆ best:epoc │
# │ ization    ┆ ization    ┆ ---      ┆ /epoch     ┆ /test_reca ┆ h/test_nd ┆ h/test_re ┆ h/test_nd │
# │ ---        ┆ ---        ┆ u32      ┆ ---        ┆ ll@10      ┆ cg@10     ┆ call@20   ┆ cg@20     │
# │ str        ┆ str        ┆          ┆ f64        ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆          ┆            ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪══════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 0.0        ┆ 0.0        ┆ 12       ┆ 14.583333  ┆ 0.021834   ┆ 0.085193  ┆ 0.038418  ┆ 0.109821  │
# │ 0.0        ┆ 1e-9       ┆ 9        ┆ 12.555556  ┆ 0.022136   ┆ 0.086464  ┆ 0.038806  ┆ 0.11102   │
# │ 0.0        ┆ 1e-8       ┆ 10       ┆ 15.4       ┆ 0.02265    ┆ 0.088068  ┆ 0.039589  ┆ 0.112997  │
# │ 0.0        ┆ 1e-7       ┆ 16       ┆ 58.0625    ┆ 0.028076   ┆ 0.106437  ┆ 0.048684  ┆ 0.134407  │
# │ 0.0        ┆ 1e-6       ┆ 12       ┆ 51.333333  ┆ 0.025898   ┆ 0.10048   ┆ 0.044898  ┆ 0.126195  │
# │ 0.0        ┆ 0.00001    ┆ 8        ┆ 57.5       ┆ 0.012032   ┆ 0.051095  ┆ 0.021054  ┆ 0.065463  │
# │ 0.0        ┆ 0.0001     ┆ 10       ┆ 11.2       ┆ 0.002792   ┆ 0.012626  ┆ 0.004778  ┆ 0.016941  │
# │ 1e-9       ┆ 0.0        ┆ 10       ┆ 11.6       ┆ 0.021983   ┆ 0.085908  ┆ 0.038627  ┆ 0.110434  │
# │ 1e-9       ┆ 1e-9       ┆ 7        ┆ 17.285714  ┆ 0.022203   ┆ 0.085697  ┆ 0.039023  ┆ 0.110561  │
# │ 1e-9       ┆ 1e-8       ┆ 4        ┆ 19.75      ┆ 0.022763   ┆ 0.088144  ┆ 0.039877  ┆ 0.113323  │
# │ …          ┆ …          ┆ …        ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 0.00001    ┆ 1e-6       ┆ 3        ┆ 54.0       ┆ 0.000348   ┆ 0.00161   ┆ 0.000693  ┆ 0.002469  │
# │ 0.00001    ┆ 0.00001    ┆ 6        ┆ 9.5        ┆ 0.000227   ┆ 0.001042  ┆ 0.000466  ┆ 0.001649  │
# │ 0.00001    ┆ 0.0001     ┆ 7        ┆ 38.285714  ┆ 0.000285   ┆ 0.001303  ┆ 0.000559  ┆ 0.002003  │
# │ 0.0001     ┆ 0.0        ┆ 7        ┆ 3.571429   ┆ 0.000279   ┆ 0.001323  ┆ 0.000552  ┆ 0.002011  │
# │ 0.0001     ┆ 1e-9       ┆ 7        ┆ 12.428571  ┆ 0.000267   ┆ 0.00124   ┆ 0.000554  ┆ 0.001973  │
# │ 0.0001     ┆ 1e-8       ┆ 6        ┆ 5.5        ┆ 0.000273   ┆ 0.001301  ┆ 0.000537  ┆ 0.001989  │
# │ 0.0001     ┆ 1e-7       ┆ 5        ┆ 12.4       ┆ 0.000278   ┆ 0.00125   ┆ 0.000566  ┆ 0.001972  │
# │ 0.0001     ┆ 1e-6       ┆ 8        ┆ 13.875     ┆ 0.000268   ┆ 0.001295  ┆ 0.000531  ┆ 0.001973  │
# │ 0.0001     ┆ 0.00001    ┆ 3        ┆ 21.0       ┆ 0.000297   ┆ 0.001414  ┆ 0.000581  ┆ 0.002106  │
# │ 0.0001     ┆ 0.0001     ┆ 5        ┆ 44.8       ┆ 0.000335   ┆ 0.001461  ┆ 0.000642  ┆ 0.002218  │
# └────────────┴────────────┴──────────┴────────────┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="l1_regularization",
    columns="l2_regularization"
)
# Out:
# /tmp/ipykernel_2703953/1305047977.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
# shape: (7, 8)
# ┌───────────────────┬─────┬──────┬──────┬──────┬──────┬─────────┬────────┐
# │ l1_regularization ┆ 0.0 ┆ 1e-9 ┆ 1e-8 ┆ 1e-7 ┆ 1e-6 ┆ 0.00001 ┆ 0.0001 │
# │ ---               ┆ --- ┆ ---  ┆ ---  ┆ ---  ┆ ---  ┆ ---     ┆ ---    │
# │ str               ┆ u32 ┆ u32  ┆ u32  ┆ u32  ┆ u32  ┆ u32     ┆ u32    │
# ╞═══════════════════╪═════╪══════╪══════╪══════╪══════╪═════════╪════════╡
# │ 0.0               ┆ 12  ┆ 9    ┆ 10   ┆ 16   ┆ 12   ┆ 8       ┆ 10     │
# │ 1e-9              ┆ 10  ┆ 7    ┆ 4    ┆ 4    ┆ 2    ┆ 5       ┆ 5      │
# │ 1e-8              ┆ 9   ┆ 9    ┆ 7    ┆ 3    ┆ 7    ┆ 3       ┆ 5      │
# │ 1e-7              ┆ 10  ┆ 6    ┆ 7    ┆ 2    ┆ 6    ┆ 4       ┆ 6      │
# │ 1e-6              ┆ 12  ┆ 2    ┆ 4    ┆ 6    ┆ 4    ┆ 6       ┆ 9      │
# │ 0.00001           ┆ 15  ┆ 4    ┆ 2    ┆ 6    ┆ 3    ┆ 6       ┆ 7      │
# │ 0.0001            ┆ 7   ┆ 7    ┆ 6    ┆ 5    ┆ 8    ┆ 3       ┆ 5      │
# └───────────────────┴─────┴──────┴──────┴──────┴──────┴─────────┴────────┘

# %% [markdown]
# ### Best Epoch

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/epoch"]].pivot(
        values=["best:epoch/epoch"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="Blues", axis=None)
    .format("{:.2f}")
)
# Out:
# <style type="text/css">
# #T_2da3c_row0_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_2da3c_row0_col1, #T_2da3c_row6_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_2da3c_row0_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_2da3c_row0_col3, #T_2da3c_row1_col5 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_2da3c_row0_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_2da3c_row0_col5 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_2da3c_row0_col6 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_2da3c_row1_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_2da3c_row1_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_2da3c_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_2da3c_row1_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_2da3c_row1_col4 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_2da3c_row1_col6, #T_2da3c_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2da3c_row2_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_2da3c_row2_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_2da3c_row2_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_2da3c_row2_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_2da3c_row2_col4 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_2da3c_row2_col5 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_2da3c_row2_col6 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_2da3c_row3_col0, #T_2da3c_row3_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_2da3c_row3_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_2da3c_row3_col3, #T_2da3c_row5_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_2da3c_row3_col4 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_2da3c_row3_col5 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_2da3c_row4_col0, #T_2da3c_row4_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_2da3c_row4_col1 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_2da3c_row4_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_2da3c_row4_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_2da3c_row4_col5 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_2da3c_row4_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2da3c_row5_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_2da3c_row5_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_2da3c_row5_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_2da3c_row5_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_2da3c_row5_col5 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_2da3c_row5_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_2da3c_row6_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2da3c_row6_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_2da3c_row6_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_2da3c_row6_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_2da3c_row6_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_2da3c_row6_col6 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2da3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2da3c_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_2da3c_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_2da3c_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_2da3c_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_2da3c_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_2da3c_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_2da3c_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2da3c_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_2da3c_row0_col0" class="data row0 col0" >14.58</td>
#       <td id="T_2da3c_row0_col1" class="data row0 col1" >12.56</td>
#       <td id="T_2da3c_row0_col2" class="data row0 col2" >15.40</td>
#       <td id="T_2da3c_row0_col3" class="data row0 col3" >58.06</td>
#       <td id="T_2da3c_row0_col4" class="data row0 col4" >51.33</td>
#       <td id="T_2da3c_row0_col5" class="data row0 col5" >57.50</td>
#       <td id="T_2da3c_row0_col6" class="data row0 col6" >11.20</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_2da3c_row1_col0" class="data row1 col0" >11.60</td>
#       <td id="T_2da3c_row1_col1" class="data row1 col1" >17.29</td>
#       <td id="T_2da3c_row1_col2" class="data row1 col2" >19.75</td>
#       <td id="T_2da3c_row1_col3" class="data row1 col3" >59.25</td>
#       <td id="T_2da3c_row1_col4" class="data row1 col4" >45.50</td>
#       <td id="T_2da3c_row1_col5" class="data row1 col5" >58.00</td>
#       <td id="T_2da3c_row1_col6" class="data row1 col6" >61.20</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_2da3c_row2_col0" class="data row2 col0" >16.00</td>
#       <td id="T_2da3c_row2_col1" class="data row2 col1" >17.67</td>
#       <td id="T_2da3c_row2_col2" class="data row2 col2" >22.29</td>
#       <td id="T_2da3c_row2_col3" class="data row2 col3" >58.67</td>
#       <td id="T_2da3c_row2_col4" class="data row2 col4" >59.57</td>
#       <td id="T_2da3c_row2_col5" class="data row2 col5" >57.33</td>
#       <td id="T_2da3c_row2_col6" class="data row2 col6" >59.40</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_2da3c_row3_col0" class="data row3 col0" >23.40</td>
#       <td id="T_2da3c_row3_col1" class="data row3 col1" >22.83</td>
#       <td id="T_2da3c_row3_col2" class="data row3 col2" >23.43</td>
#       <td id="T_2da3c_row3_col3" class="data row3 col3" >54.00</td>
#       <td id="T_2da3c_row3_col4" class="data row3 col4" >42.00</td>
#       <td id="T_2da3c_row3_col5" class="data row3 col5" >58.50</td>
#       <td id="T_2da3c_row3_col6" class="data row3 col6" >61.17</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_2da3c_row4_col0" class="data row4 col0" >48.92</td>
#       <td id="T_2da3c_row4_col1" class="data row4 col1" >24.50</td>
#       <td id="T_2da3c_row4_col2" class="data row4 col2" >49.00</td>
#       <td id="T_2da3c_row4_col3" class="data row4 col3" >46.33</td>
#       <td id="T_2da3c_row4_col4" class="data row4 col4" >22.50</td>
#       <td id="T_2da3c_row4_col5" class="data row4 col5" >35.67</td>
#       <td id="T_2da3c_row4_col6" class="data row4 col6" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_2da3c_row5_col0" class="data row5 col0" >44.07</td>
#       <td id="T_2da3c_row5_col1" class="data row5 col1" >50.25</td>
#       <td id="T_2da3c_row5_col2" class="data row5 col2" >36.50</td>
#       <td id="T_2da3c_row5_col3" class="data row5 col3" >49.33</td>
#       <td id="T_2da3c_row5_col4" class="data row5 col4" >54.00</td>
#       <td id="T_2da3c_row5_col5" class="data row5 col5" >9.50</td>
#       <td id="T_2da3c_row5_col6" class="data row5 col6" >38.29</td>
#     </tr>
#     <tr>
#       <th id="T_2da3c_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_2da3c_row6_col0" class="data row6 col0" >3.57</td>
#       <td id="T_2da3c_row6_col1" class="data row6 col1" >12.43</td>
#       <td id="T_2da3c_row6_col2" class="data row6 col2" >5.50</td>
#       <td id="T_2da3c_row6_col3" class="data row6 col3" >12.40</td>

# %% [markdown]
# ### Best Test Recall@20

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/test_recall@20"]].pivot(
        values=["best:epoch/test_recall@20"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_55a86_row0_col0 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_55a86_row0_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_55a86_row0_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_55a86_row0_col3, #T_55a86_row1_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_55a86_row0_col4, #T_55a86_row3_col0 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_55a86_row0_col5 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_55a86_row0_col6 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_55a86_row1_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_55a86_row1_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_55a86_row1_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_55a86_row1_col4 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_55a86_row1_col5, #T_55a86_row2_col5 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_55a86_row1_col6 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_55a86_row2_col0, #T_55a86_row2_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_55a86_row2_col2 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_55a86_row2_col3, #T_55a86_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_55a86_row2_col4, #T_55a86_row3_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_55a86_row2_col6, #T_55a86_row3_col6 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_55a86_row3_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_55a86_row3_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_55a86_row3_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_55a86_row4_col0 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_55a86_row4_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_55a86_row4_col2, #T_55a86_row4_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_55a86_row4_col4 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_55a86_row4_col5, #T_55a86_row5_col0, #T_55a86_row5_col1, #T_55a86_row5_col3, #T_55a86_row5_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_55a86_row4_col6, #T_55a86_row5_col2, #T_55a86_row5_col5, #T_55a86_row5_col6, #T_55a86_row6_col0, #T_55a86_row6_col1, #T_55a86_row6_col2, #T_55a86_row6_col3, #T_55a86_row6_col4, #T_55a86_row6_col5, #T_55a86_row6_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_55a86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55a86_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_55a86_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_55a86_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_55a86_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_55a86_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_55a86_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_55a86_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55a86_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_55a86_row0_col0" class="data row0 col0" >0.038418</td>
#       <td id="T_55a86_row0_col1" class="data row0 col1" >0.038806</td>
#       <td id="T_55a86_row0_col2" class="data row0 col2" >0.039589</td>
#       <td id="T_55a86_row0_col3" class="data row0 col3" >0.048684</td>
#       <td id="T_55a86_row0_col4" class="data row0 col4" >0.044898</td>
#       <td id="T_55a86_row0_col5" class="data row0 col5" >0.021054</td>
#       <td id="T_55a86_row0_col6" class="data row0 col6" >0.004778</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_55a86_row1_col0" class="data row1 col0" >0.038627</td>
#       <td id="T_55a86_row1_col1" class="data row1 col1" >0.039023</td>
#       <td id="T_55a86_row1_col2" class="data row1 col2" >0.039877</td>
#       <td id="T_55a86_row1_col3" class="data row1 col3" >0.048698</td>
#       <td id="T_55a86_row1_col4" class="data row1 col4" >0.045148</td>
#       <td id="T_55a86_row1_col5" class="data row1 col5" >0.020508</td>
#       <td id="T_55a86_row1_col6" class="data row1 col6" >0.003351</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_55a86_row2_col0" class="data row2 col0" >0.040153</td>
#       <td id="T_55a86_row2_col1" class="data row2 col1" >0.040324</td>
#       <td id="T_55a86_row2_col2" class="data row2 col2" >0.041442</td>
#       <td id="T_55a86_row2_col3" class="data row2 col3" >0.049503</td>
#       <td id="T_55a86_row2_col4" class="data row2 col4" >0.045028</td>
#       <td id="T_55a86_row2_col5" class="data row2 col5" >0.020424</td>
#       <td id="T_55a86_row2_col6" class="data row2 col6" >0.002356</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_55a86_row3_col0" class="data row3 col0" >0.044897</td>
#       <td id="T_55a86_row3_col1" class="data row3 col1" >0.044934</td>
#       <td id="T_55a86_row3_col2" class="data row3 col2" >0.045462</td>
#       <td id="T_55a86_row3_col3" class="data row3 col3" >0.049522</td>
#       <td id="T_55a86_row3_col4" class="data row3 col4" >0.044442</td>
#       <td id="T_55a86_row3_col5" class="data row3 col5" >0.022064</td>
#       <td id="T_55a86_row3_col6" class="data row3 col6" >0.002213</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_55a86_row4_col0" class="data row4 col0" >0.033991</td>
#       <td id="T_55a86_row4_col1" class="data row4 col1" >0.031759</td>
#       <td id="T_55a86_row4_col2" class="data row4 col2" >0.035241</td>
#       <td id="T_55a86_row4_col3" class="data row4 col3" >0.035338</td>
#       <td id="T_55a86_row4_col4" class="data row4 col4" >0.032858</td>
#       <td id="T_55a86_row4_col5" class="data row4 col5" >0.000804</td>
#       <td id="T_55a86_row4_col6" class="data row4 col6" >0.000484</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_55a86_row5_col0" class="data row5 col0" >0.000664</td>
#       <td id="T_55a86_row5_col1" class="data row5 col1" >0.000669</td>
#       <td id="T_55a86_row5_col2" class="data row5 col2" >0.000641</td>
#       <td id="T_55a86_row5_col3" class="data row5 col3" >0.000675</td>
#       <td id="T_55a86_row5_col4" class="data row5 col4" >0.000693</td>
#       <td id="T_55a86_row5_col5" class="data row5 col5" >0.000466</td>
#       <td id="T_55a86_row5_col6" class="data row5 col6" >0.000559</td>
#     </tr>
#     <tr>
#       <th id="T_55a86_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_55a86_row6_col0" class="data row6 col0" >0.000552</td>
#       <td id="T_55a86_row6_col1" class="data row6 col1" >0.000554</td>
#       <td id="T_55a86_row6_col2" class="data row6 col2" >0.000537</td>
#       <td id="T_55a86_row6_col3" class="data row6 col3" >0.000566</td>
#       <td id="T_55a86_row6_col4" class="data row6 col4" >0.000531</td>
#       <td id="T_55a86_row6_col5" class="data row6 col5" >0.000581</td>
#       <td id="T_55a86_row6_col6" class="data row6 col6" >0.000642</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Best Test NDCG@20

# %%
(
    experiment_summary[["l1_regularization", "l2_regularization", "best:epoch/test_ndcg@20"]].pivot(
        values=["best:epoch/test_ndcg@20"],
        index="l1_regularization",
        on="l2_regularization"
    )
    .to_pandas()
    .set_index("l1_regularization")
    .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_ffa52_row0_col0 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_ffa52_row0_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_ffa52_row0_col2, #T_ffa52_row1_col2 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_ffa52_row0_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_ffa52_row0_col4, #T_ffa52_row1_col4, #T_ffa52_row3_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_ffa52_row0_col5 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_ffa52_row0_col6 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_ffa52_row1_col0, #T_ffa52_row1_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_ffa52_row1_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_ffa52_row1_col5 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_ffa52_row1_col6 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_ffa52_row2_col0, #T_ffa52_row2_col1 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_ffa52_row2_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_ffa52_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ffa52_row2_col4, #T_ffa52_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_ffa52_row2_col5 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_ffa52_row2_col6 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_ffa52_row3_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_ffa52_row3_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_ffa52_row3_col4 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_ffa52_row3_col5 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_ffa52_row3_col6 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_ffa52_row4_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_ffa52_row4_col1 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_ffa52_row4_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_ffa52_row4_col3 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_ffa52_row4_col4 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_ffa52_row4_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_ffa52_row4_col6, #T_ffa52_row5_col5, #T_ffa52_row5_col6, #T_ffa52_row6_col0, #T_ffa52_row6_col1, #T_ffa52_row6_col2, #T_ffa52_row6_col3, #T_ffa52_row6_col4, #T_ffa52_row6_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ffa52_row5_col0, #T_ffa52_row5_col1, #T_ffa52_row5_col2, #T_ffa52_row5_col3, #T_ffa52_row5_col4, #T_ffa52_row6_col6 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ffa52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa52_level0_col0" class="col_heading level0 col0" >0.0</th>
#       <th id="T_ffa52_level0_col1" class="col_heading level0 col1" >1e-9</th>
#       <th id="T_ffa52_level0_col2" class="col_heading level0 col2" >1e-8</th>
#       <th id="T_ffa52_level0_col3" class="col_heading level0 col3" >1e-7</th>
#       <th id="T_ffa52_level0_col4" class="col_heading level0 col4" >1e-6</th>
#       <th id="T_ffa52_level0_col5" class="col_heading level0 col5" >0.00001</th>
#       <th id="T_ffa52_level0_col6" class="col_heading level0 col6" >0.0001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l1_regularization</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffa52_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_ffa52_row0_col0" class="data row0 col0" >0.109821</td>
#       <td id="T_ffa52_row0_col1" class="data row0 col1" >0.111020</td>
#       <td id="T_ffa52_row0_col2" class="data row0 col2" >0.112997</td>
#       <td id="T_ffa52_row0_col3" class="data row0 col3" >0.134407</td>
#       <td id="T_ffa52_row0_col4" class="data row0 col4" >0.126195</td>
#       <td id="T_ffa52_row0_col5" class="data row0 col5" >0.065463</td>
#       <td id="T_ffa52_row0_col6" class="data row0 col6" >0.016941</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row1" class="row_heading level0 row1" >1e-9</th>
#       <td id="T_ffa52_row1_col0" class="data row1 col0" >0.110434</td>
#       <td id="T_ffa52_row1_col1" class="data row1 col1" >0.110561</td>
#       <td id="T_ffa52_row1_col2" class="data row1 col2" >0.113323</td>
#       <td id="T_ffa52_row1_col3" class="data row1 col3" >0.134506</td>
#       <td id="T_ffa52_row1_col4" class="data row1 col4" >0.126176</td>
#       <td id="T_ffa52_row1_col5" class="data row1 col5" >0.064525</td>
#       <td id="T_ffa52_row1_col6" class="data row1 col6" >0.012739</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row2" class="row_heading level0 row2" >1e-8</th>
#       <td id="T_ffa52_row2_col0" class="data row2 col0" >0.113905</td>
#       <td id="T_ffa52_row2_col1" class="data row2 col1" >0.114235</td>
#       <td id="T_ffa52_row2_col2" class="data row2 col2" >0.116818</td>
#       <td id="T_ffa52_row2_col3" class="data row2 col3" >0.136560</td>
#       <td id="T_ffa52_row2_col4" class="data row2 col4" >0.125889</td>
#       <td id="T_ffa52_row2_col5" class="data row2 col5" >0.063955</td>
#       <td id="T_ffa52_row2_col6" class="data row2 col6" >0.009460</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row3" class="row_heading level0 row3" >1e-7</th>
#       <td id="T_ffa52_row3_col0" class="data row3 col0" >0.126193</td>
#       <td id="T_ffa52_row3_col1" class="data row3 col1" >0.125974</td>
#       <td id="T_ffa52_row3_col2" class="data row3 col2" >0.127672</td>
#       <td id="T_ffa52_row3_col3" class="data row3 col3" >0.135343</td>
#       <td id="T_ffa52_row3_col4" class="data row3 col4" >0.124198</td>
#       <td id="T_ffa52_row3_col5" class="data row3 col5" >0.066533</td>
#       <td id="T_ffa52_row3_col6" class="data row3 col6" >0.008567</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row4" class="row_heading level0 row4" >1e-6</th>
#       <td id="T_ffa52_row4_col0" class="data row4 col0" >0.097293</td>
#       <td id="T_ffa52_row4_col1" class="data row4 col1" >0.091937</td>
#       <td id="T_ffa52_row4_col2" class="data row4 col2" >0.099727</td>
#       <td id="T_ffa52_row4_col3" class="data row4 col3" >0.101127</td>
#       <td id="T_ffa52_row4_col4" class="data row4 col4" >0.094650</td>
#       <td id="T_ffa52_row4_col5" class="data row4 col5" >0.002864</td>
#       <td id="T_ffa52_row4_col6" class="data row4 col6" >0.001762</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row5" class="row_heading level0 row5" >0.00001</th>
#       <td id="T_ffa52_row5_col0" class="data row5 col0" >0.002445</td>
#       <td id="T_ffa52_row5_col1" class="data row5 col1" >0.002444</td>
#       <td id="T_ffa52_row5_col2" class="data row5 col2" >0.002284</td>
#       <td id="T_ffa52_row5_col3" class="data row5 col3" >0.002413</td>
#       <td id="T_ffa52_row5_col4" class="data row5 col4" >0.002469</td>
#       <td id="T_ffa52_row5_col5" class="data row5 col5" >0.001649</td>
#       <td id="T_ffa52_row5_col6" class="data row5 col6" >0.002003</td>
#     </tr>
#     <tr>
#       <th id="T_ffa52_level0_row6" class="row_heading level0 row6" >0.0001</th>
#       <td id="T_ffa52_row6_col0" class="data row6 col0" >0.002011</td>
#       <td id="T_ffa52_row6_col1" class="data row6 col1" >0.001973</td>
#       <td id="T_ffa52_row6_col2" class="data row6 col2" >0.001989</td>
#       <td id="T_ffa52_row6_col3" class="data row6 col3" >0.001972</td>
#       <td id="T_ffa52_row6_col4" class="data row6 col4" >0.001973</td>
#       <td id="T_ffa52_row6_col5" class="data row6 col5" >0.002106</td>
#       <td id="T_ffa52_row6_col6" class="data row6 col6" >0.002218</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## ElasticNet, D=256, Shuffle = False

# %%
experiment_summary = experiment_runs.filter(
    pl.col("shuffle") == False,
    pl.col("embedding_dimension") == 256,
    pl.col("l1_regularization") != 1e-10, pl.col("l1_regularization") <= 1e-4,
    pl.col("l2_regularization") != 1e-10, pl.col("l2_regularization") <= 1e-4,
    pl.col("embedding_dropout_rate") == 0.0
).group_by(
    "l1_regularization", "l2_regularization"
).agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@20").mean(),
    pl.col("best:epoch/test_ndcg@20").mean(),
).sort(
    "l1_regularization", "l2_regularization"
).with_columns(
    pl.col("l1_regularization").cast(pl.Utf8),
    pl.col("l2_regularization").cast(pl.Utf8)
)

# %% [markdown]
# ### Run Counts

# %%
experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
    values=["num_runs"],
    index="l1_regularization",
    columns="l2_regularization"
)
# Out:
# /tmp/ipykernel_2703953/1305047977.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["l1_regularization", "l2_regularization", "num_runs"]].pivot(
# shape: (7, 8)
# ┌───────────────────┬─────┬──────┬──────┬──────┬──────┬─────────┬────────┐
# │ l1_regularization ┆ 0.0 ┆ 1e-9 ┆ 1e-8 ┆ 1e-7 ┆ 1e-6 ┆ 0.00001 ┆ 0.0001 │
# │ ---               ┆ --- ┆ ---  ┆ ---  ┆ ---  ┆ ---  ┆ ---     ┆ ---    │
# │ str               ┆ u32 ┆ u32  ┆ u32  ┆ u32  ┆ u32  ┆ u32     ┆ u32    │
# ╞═══════════════════╪═════╪══════╪══════╪══════╪══════╪═════════╪════════╡
# │ 0.0               ┆ 10  ┆ 4    ┆ 4    ┆ 5    ┆ 4    ┆ 5       ┆ 4      │
# │ 1e-9              ┆ 3   ┆ null ┆ null ┆ null ┆ 1    ┆ 1       ┆ 1      │
# │ 1e-8              ┆ 3   ┆ null ┆ null ┆ 1    ┆ 2    ┆ 1       ┆ null   │
# │ 1e-7              ┆ 8   ┆ null ┆ 2    ┆ 2    ┆ null ┆ null    ┆ null   │
# │ 1e-6              ┆ 4   ┆ null ┆ null ┆ null ┆ null ┆ 1       ┆ null   │
# │ 0.00001           ┆ 5   ┆ null ┆ null ┆ 1    ┆ 1    ┆ 2       ┆ null   │
# │ 0.0001            ┆ 3   ┆ null ┆ null ┆ null ┆ 2    ┆ 1       ┆ 2      │
# └───────────────────┴─────┴──────┴──────┴──────┴──────┴─────────┴────────┘

# %% [markdown]
# # Cross-GPU Training

# %%
experiment_runs.group_by("embedding_dimension").agg(
    pl.col("run_duration_minute").mean()
).sort("embedding_dimension")
# Out:
# shape: (10, 2)
# ┌─────────────────────┬─────────────────────┐
# │ embedding_dimension ┆ run_duration_minute │
# │ ---                 ┆ ---                 │
# │ i64                 ┆ f64                 │
# ╞═════════════════════╪═════════════════════╡
# │ 2                   ┆ 12.446437           │
# │ 4                   ┆ 12.438744           │
# │ 8                   ┆ 12.333611           │
# │ 16                  ┆ 12.487377           │
# │ 32                  ┆ 12.445287           │
# │ 64                  ┆ 12.740832           │
# │ 128                 ┆ 12.348307           │
# │ 256                 ┆ 12.778              │
# │ 512                 ┆ 13.610148           │
# │ 1024                ┆ 16.095069           │
# └─────────────────────┴─────────────────────┘

# %%
experiment_runs.group_by("gpu_type").agg(
    pl.col("run_duration_minute").mean(),
    
).sort("gpu_type")
# Out:
# shape: (2, 2)
# ┌─────────────┬─────────────────────┐
# │ gpu_type    ┆ run_duration_minute │
# │ ---         ┆ ---                 │
# │ str         ┆ f64                 │
# ╞═════════════╪═════════════════════╡
# │ NVIDIA A10G ┆ 12.554927           │
# │ NVIDIA L4   ┆ 17.202939           │
# └─────────────┴─────────────────────┘

# %%
experiment_summary = experiment_runs.filter(
    pl.col("l2_regularization") == 0,
    pl.col("l1_regularization") == 0.0,
    pl.col("embedding_dropout_rate") == 0.0
).group_by("embedding_dimension", "gpu_type").agg(
    pl.col("run_id").count().alias("num_runs"),
    pl.col("best:epoch/epoch").mean(),
    pl.col("best:epoch/test_recall@10").mean(),
    pl.col("best:epoch/test_ndcg@10").mean(),
    pl.col("best:epoch/test_recall@50").mean(),
    pl.col("best:epoch/test_ndcg@50").mean(),
).sort("embedding_dimension", "gpu_type")
experiment_summary
# Out:
# shape: (15, 8)
# ┌────────────┬────────────┬──────────┬────────────┬────────────┬───────────┬───────────┬───────────┐
# │ embedding_ ┆ gpu_type   ┆ num_runs ┆ best:epoch ┆ best:epoch ┆ best:epoc ┆ best:epoc ┆ best:epoc │
# │ dimension  ┆ ---        ┆ ---      ┆ /epoch     ┆ /test_reca ┆ h/test_nd ┆ h/test_re ┆ h/test_nd │
# │ ---        ┆ str        ┆ u32      ┆ ---        ┆ ll@10      ┆ cg@10     ┆ call@50   ┆ cg@50     │
# │ i64        ┆            ┆          ┆ f64        ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆          ┆            ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪══════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2          ┆ NVIDIA     ┆ 11       ┆ 49.909091  ┆ 0.015237   ┆ 0.059456  ┆ 0.054251  ┆ 0.105763  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 2          ┆ NVIDIA L4  ┆ 2        ┆ 54.5       ┆ 0.01585    ┆ 0.061646  ┆ 0.056766  ┆ 0.1099    │
# │ 4          ┆ NVIDIA     ┆ 16       ┆ 47.75      ┆ 0.0199     ┆ 0.077285  ┆ 0.070973  ┆ 0.132605  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 8          ┆ NVIDIA     ┆ 17       ┆ 50.176471  ┆ 0.021985   ┆ 0.085121  ┆ 0.078469  ┆ 0.143825  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 8          ┆ NVIDIA L4  ┆ 1        ┆ 48.0       ┆ 0.022055   ┆ 0.08557   ┆ 0.078698  ┆ 0.144032  │
# │ 16         ┆ NVIDIA     ┆ 15       ┆ 39.2       ┆ 0.022679   ┆ 0.087946  ┆ 0.080375  ┆ 0.14723   │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 16         ┆ NVIDIA L4  ┆ 1        ┆ 23.0       ┆ 0.023082   ┆ 0.089788  ┆ 0.081257  ┆ 0.148892  │
# │ 32         ┆ NVIDIA     ┆ 15       ┆ 20.2       ┆ 0.022781   ┆ 0.088311  ┆ 0.080075  ┆ 0.147322  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 64         ┆ NVIDIA     ┆ 12       ┆ 12.0       ┆ 0.022747   ┆ 0.088153  ┆ 0.079196  ┆ 0.146453  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 128        ┆ NVIDIA     ┆ 26       ┆ 10.653846  ┆ 0.022288   ┆ 0.086847  ┆ 0.077404  ┆ 0.14446   │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 128        ┆ NVIDIA L4  ┆ 1        ┆ 7.0        ┆ 0.02257    ┆ 0.08856   ┆ 0.077215  ┆ 0.145288  │
# │ 256        ┆ NVIDIA     ┆ 17       ┆ 7.647059   ┆ 0.02162    ┆ 0.083875  ┆ 0.075118  ┆ 0.140154  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 512        ┆ NVIDIA     ┆ 9        ┆ 3.0        ┆ 0.022227   ┆ 0.0852    ┆ 0.07512   ┆ 0.139369  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 512        ┆ NVIDIA L4  ┆ 2        ┆ 6.5        ┆ 0.021995   ┆ 0.085229  ┆ 0.075376  ┆ 0.140036  │
# │ 1024       ┆ NVIDIA     ┆ 14       ┆ 0.571429   ┆ 0.023215   ┆ 0.090022  ┆ 0.077101  ┆ 0.143154  │
# │            ┆ A10G       ┆          ┆            ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴──────────┴────────────┴────────────┴───────────┴───────────┴───────────┘

# %%
experiment_summary[["embedding_dimension", "gpu_type", "num_runs"]].pivot(
    values=["num_runs"],
    index="embedding_dimension",
    columns="gpu_type"
)
# Out:
# /tmp/ipykernel_1019350/1667364229.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "gpu_type", "num_runs"]].pivot(
# shape: (10, 3)
# ┌─────────────────────┬─────────────┬───────────┐
# │ embedding_dimension ┆ NVIDIA A10G ┆ NVIDIA L4 │
# │ ---                 ┆ ---         ┆ ---       │
# │ i64                 ┆ u32         ┆ u32       │
# ╞═════════════════════╪═════════════╪═══════════╡
# │ 2                   ┆ 11          ┆ 2         │
# │ 4                   ┆ 16          ┆ null      │
# │ 8                   ┆ 17          ┆ 1         │
# │ 16                  ┆ 15          ┆ 1         │
# │ 32                  ┆ 15          ┆ null      │
# │ 64                  ┆ 12          ┆ null      │
# │ 128                 ┆ 26          ┆ 1         │
# │ 256                 ┆ 17          ┆ null      │
# │ 512                 ┆ 9           ┆ 2         │
# │ 1024                ┆ 14          ┆ null      │
# └─────────────────────┴─────────────┴───────────┘

# %%
experiment_summary[["embedding_dimension", "gpu_type", "best:epoch/test_recall@50"]].pivot(
    values=["best:epoch/test_recall@50"],
    index="embedding_dimension",
    columns="gpu_type"
)
# Out:
# /tmp/ipykernel_1019350/93591780.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "gpu_type", "best:epoch/test_recall@50"]].pivot(
# shape: (10, 3)
# ┌─────────────────────┬─────────────┬───────────┐
# │ embedding_dimension ┆ NVIDIA A10G ┆ NVIDIA L4 │
# │ ---                 ┆ ---         ┆ ---       │
# │ i64                 ┆ f64         ┆ f64       │
# ╞═════════════════════╪═════════════╪═══════════╡
# │ 2                   ┆ 0.054251    ┆ 0.056766  │
# │ 4                   ┆ 0.070973    ┆ null      │
# │ 8                   ┆ 0.078469    ┆ 0.078698  │
# │ 16                  ┆ 0.080375    ┆ 0.081257  │
# │ 32                  ┆ 0.080075    ┆ null      │
# │ 64                  ┆ 0.079196    ┆ null      │
# │ 128                 ┆ 0.077404    ┆ 0.077215  │
# │ 256                 ┆ 0.075118    ┆ null      │
# │ 512                 ┆ 0.07512     ┆ 0.075376  │
# │ 1024                ┆ 0.077101    ┆ null      │
# └─────────────────────┴─────────────┴───────────┘

# %%
experiment_summary[["embedding_dimension", "gpu_type", "best:epoch/test_ndcg@50"]].pivot(
    values=["best:epoch/test_ndcg@50"],
    index="embedding_dimension",
    columns="gpu_type"
)
# Out:
# /tmp/ipykernel_1019350/2601597168.py:1: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   experiment_summary[["embedding_dimension", "gpu_type", "best:epoch/test_ndcg@50"]].pivot(
# shape: (10, 3)
# ┌─────────────────────┬─────────────┬───────────┐
# │ embedding_dimension ┆ NVIDIA A10G ┆ NVIDIA L4 │
# │ ---                 ┆ ---         ┆ ---       │
# │ i64                 ┆ f64         ┆ f64       │
# ╞═════════════════════╪═════════════╪═══════════╡
# │ 2                   ┆ 0.105763    ┆ 0.1099    │
# │ 4                   ┆ 0.132605    ┆ null      │
# │ 8                   ┆ 0.143825    ┆ 0.144032  │
# │ 16                  ┆ 0.14723     ┆ 0.148892  │
# │ 32                  ┆ 0.147322    ┆ null      │
# │ 64                  ┆ 0.146453    ┆ null      │
# │ 128                 ┆ 0.14446     ┆ 0.145288  │
# │ 256                 ┆ 0.140154    ┆ null      │
# │ 512                 ┆ 0.139369    ┆ 0.140036  │
# │ 1024                ┆ 0.143154    ┆ null      │
# └─────────────────────┴─────────────┴───────────┘
