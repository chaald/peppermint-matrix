# %% [markdown]
# # Adjust WandB
#
# This notebook is to make small adjsutment to wandb tracked runs if necesary.
# Example usage:
# - Add default value to parameter that is previously unavailable

# %%
import wandb
from wandb.apis.public import Run
from typing import List

api = wandb.Api()
runs: List[Run] = api.runs("feedr/peppermint-matrix")
# Out:
# failed to send, dropping 5 traces to intake at http://localhost:8126/v0.5/traces after 3 retries
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/hafidh_rendyanto/.netrc.

# %%
run_count = 0
for run in runs:
    if run.config.get("model") == "matrix_factorization":
        if run.config.get("store_model") is None:
            run.config["store_model"] = False  # Set default value
            run.update()
            run_count += 1
            print(run.name, run.state, run.id)

print(f"Total runs with missing store_model: {run_count}")
# Out:
# failed to send, dropping 2 traces to intake at http://localhost:8126/v0.5/traces after 3 retries, 2 additional messages skipped
# laced-sweep-4 finished yszchdsw
# electric-sweep-1 finished sm4faeql
# solar-sweep-3 finished mhh2vww3
# lively-sweep-2 finished im0wjtep
# clean-sweep-5 finished gkt242cc
# rose-sweep-6 finished yvji2dcx
# warm-sweep-7 finished n9r3cmud
# twilight-sweep-8 finished eg5qej8g
# fallen-sweep-9 finished tw2l0zlb
# visionary-sweep-10 finished 5upp90iz
# giddy-sweep-11 finished xbs4urht
# cerulean-sweep-12 finished ja3jqqw3
# vital-sweep-13 finished f5cic9t6
# summer-sweep-14 finished 203cnz96
# upbeat-sweep-15 finished jg3ufnum
# jumping-sweep-16 finished 34dspwip
# sage-sweep-17 finished 2lp8oweh
# fancy-sweep-18 finished pucaync9
# lively-sweep-19 finished wv81db96
# bright-sweep-20 finished 6steccmg
# distinctive-sweep-21 finished f0l9uq1t
# trim-sweep-22 finished nwxt37sn
# polar-sweep-23 finished xvj5foah
# laced-sweep-24 finished qyezft5j
# wandering-sweep-25 finished zu5cxbjr
# brisk-sweep-26 finished nauqbrh0
# fragrant-sweep-27 finished 7ka7ulm0
# stellar-sweep-28 finished fccpx7qu
# wise-sweep-29 finished r4nuq3am
# fresh-sweep-30 finished 2jow8i7u
# lively-sweep-31 finished 1npdy0in
# bumbling-sweep-32 finished g2adw2hi
# failed to send, dropping 3 traces to intake at http://localhost:8126/v0.5/traces after 3 retries, 38 additional messages skipped
# lyric-sweep-33 finished qofvkqdo
# whole-sweep-34 finished 7a8ig60v
# good-sweep-35 finished 0diaqddk
# helpful-sweep-36 finished j2duyi2g
# sweet-sweep-37 finished 9wh5d469
# major-sweep-38 finished ub7ip7x6
# deft-sweep-39 finished iymfa35v
# sage-sweep-40 finished yihe6xe1
# legendary-sweep-41 finished oda9d1or
# legendary-sweep-42 finished 5a1xcp04
# peachy-sweep-43 finished nwv83bj5
# vocal-sweep-44 finished 219sf596
# giddy-sweep-45 finished wf4dioot
# scarlet-sweep-46 finished zjicmh7b
# dulcet-sweep-47 finished 0q9nvxe0
# comfy-sweep-48 finished q8mg6qoo
# gentle-sweep-49 finished 5ip3d8at
# helpful-sweep-50 finished 2ybgoxbd
# rosy-sweep-51 finished s3y40az0
# ancient-sweep-52 finished 8h7pblh6
# earthy-sweep-53 finished pbex56el
# sweepy-sweep-54 finished ll0muhje
# rich-sweep-55 finished 1xe5031g
# colorful-sweep-56 finished jpi4gnl1
# comic-sweep-57 finished f0syuu3w
# sweet-sweep-58 finished kzcvrfi3
# blooming-sweep-59 finished d7sp23rh
# floral-sweep-60 finished i0kyuta7
# spring-sweep-61 finished fnn445hb
# gentle-sweep-62 finished w7pjraaq
# kind-sweep-63 finished pgu80i6m
# vocal-sweep-64 finished cls2ihtl
# Total runs with missing store_model: 64
