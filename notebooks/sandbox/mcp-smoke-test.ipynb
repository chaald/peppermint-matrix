# %% [markdown]
# New Notebook Created by Jupyter MCP Server

# %%
print('cell 1: hello from MCP')
# Out:
# cell 1: hello from MCP

# %%
value = 40 + 3
print('cell 2 edited:', value)
# Out:
# cell 2 edited: 43
