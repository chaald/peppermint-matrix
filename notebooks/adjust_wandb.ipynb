# %% [markdown]
# # Adjust WandB
#
# This notebook is to make small adjsutment to wandb tracked runs if necesary.
# Example usage:
# - Add default value to parameter that is previously unavailable

# %%
import wandb
from wandb.apis.public import Run
from typing import List

api = wandb.Api()
runs: List[Run] = api.runs("feedr/peppermint-matrix")
# Out:
# failed to send, dropping 1 traces to intake at http://localhost:8126/v0.5/traces after 3 retries
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/hafidh_rendyanto/.netrc.

# %%
run_count = 0
for run in runs:
    break
    if run.config.get("model") == "matrix_factorization":
        if run.config.get("store_model") is None:
            run.config["store_model"] = False  # Set default value
            run.update()
            run_count += 1
            print(run.name, run.state, run.id)

print(f"Total runs with missing store_model: {run_count}")
# Out:
# failed to send, dropping 5 traces to intake at http://localhost:8126/v0.5/traces after 3 retries, 7 additional messages skipped
# Total runs with missing store_model: 0
